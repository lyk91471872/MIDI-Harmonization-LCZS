# %%
import pickle
#with open('/path/to/your/file/jsb-chorales-16th.pkl', 'rb') as p:
with open('/Users/cui/Documents/GitHub/MIDI-Harmonization-LCZS/JSB-Chorales-dataset-master/jsb-chorales-16th.pkl', 'rb') as p:
    data = pickle.load(p, encoding="latin1")

# %%
import numpy as np
import os

# Print current working directory (to verify file location)
print("Current working directory:", os.getcwd())


# Check the type of the data
print("Type of loaded data:", type(data))

# If the data is a dictionary, list the keys and number of items in each.
if isinstance(data, dict):
    for key, value in data.items():
        print(f"Key: {key}, Number of chorales: {len(value)}")
elif isinstance(data, list):
    print("Number of chorales in dataset:", len(data))
# Out:
# Current working directory: /Users/cui/Documents/GitHub/MIDI-Harmonization-LCZS
# Type of loaded data: <class 'collections.defaultdict'>
# Key: test, Number of chorales: 77
# Key: train, Number of chorales: 229
# Key: valid, Number of chorales: 76
# Key: 0, Number of chorales: 0

# %%
import numpy as np

# Initialize a variable for a valid chorale.
chosen = None

if isinstance(data, list):
    for i, chor in enumerate(data):
        chor_array = np.array(chor)
        # Print the shape to inspect it
        print(f"Chorale {i} shape: {chor_array.shape}")
        # Check for a valid chorale shape (ensure it is 2D and not empty)
        if chor_array.ndim == 2 and chor_array.size != 0:
            chosen = chor_array
            print(f"Using chorale {i} for visualization.")
            break
elif isinstance(data, dict):
    # For example, use the 'train' key if it exists.
    for key in data:
        for i, chor in enumerate(data[key]):
            chor_array = np.array(chor)
            print(f"Chorale {i} in {key} shape: {chor_array.shape}")
            if chor_array.ndim == 2 and chor_array.size != 0:
                chosen = chor_array
                print(f"Using chorale {i} from '{key}' for visualization.")
                break
        if chosen is not None:
            break

if chosen is None:
    raise ValueError("No suitable chorale found for visualization.")
# Out:
# Chorale 0 in test shape: (228, 4)
# Using chorale 0 from 'test' for visualization.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os


# Select chorale 0 from the 'test' key
chorale = data['test'][0]  # chorale shape: (228, 4)
chorale_array = np.array(chorale)

# (Optional) Print the first few rows to verify the columns
print("First 5 rows of the selected chorale:")
print(chorale_array[:5])

# Create a scatter plot
plt.figure(figsize=(12, 6))
# Using column 0 (onset) as x, column 2 (pitch) as y, and column 3 for color coding
sc = plt.scatter(chorale_array[:, 0], chorale_array[:, 2], c=chorale_array[:, 3], cmap='viridis', marker='o')
plt.xlabel('Onset Time')
plt.ylabel('Pitch')
plt.title('JSB Chorale Visualization – Scatter Plot of Note Events')
plt.colorbar(sc, label='Voice (or other attribute)')
plt.show()
# Out:
# First 5 rows of the selected chorale:
# [[65 60 57 53]
#  [65 60 57 53]
#  [65 60 57 53]
#  [65 60 57 53]
#  [72 60 55 52]]

# %%
import numpy as np
import matplotlib.pyplot as plt



# Select chorale 0 from the 'test' key
chorale = data['test'][0]  # chorale shape: (228, 4)
chorale_array = np.array(chorale)

# (Optional) Print the first few rows to verify the columns
print("First 5 rows of the selected chorale:")
print(chorale_array[:5])

# Extract columns (adjust these indices if your column meanings differ)
onset   = chorale_array[:, 0]
duration = chorale_array[:, 1]
pitch   = chorale_array[:, 2]
# column 3 is available for additional use (e.g. voice) if desired

plt.figure(figsize=(12, 6))
for o, d, p in zip(onset, duration, pitch):
    # Plot a horizontal line from the onset time to onset + duration at the given pitch
    plt.hlines(p, o, o + d, colors='b', lw=2)

plt.xlabel('Time')
plt.ylabel('Pitch')
plt.title('JSB Chorale Visualization – Note Durations')
plt.show()
# Out:
# First 5 rows of the selected chorale:
# [[65 60 57 53]
#  [65 60 57 53]
#  [65 60 57 53]
#  [65 60 57 53]
#  [72 60 55 52]]

# %%
# !pip install pretty_midi
# Out:
# Requirement already satisfied: pretty_midi in /opt/anaconda3/envs/sb/lib/python3.10/site-packages (0.2.10)
# Requirement already satisfied: numpy>=1.7.0 in /opt/anaconda3/envs/sb/lib/python3.10/site-packages (from pretty_midi) (1.26.4)
# Requirement already satisfied: mido>=1.1.16 in /opt/anaconda3/envs/sb/lib/python3.10/site-packages (from pretty_midi) (1.3.3)
# Requirement already satisfied: six in /opt/anaconda3/envs/sb/lib/python3.10/site-packages (from pretty_midi) (1.16.0)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/sb/lib/python3.10/site-packages (from mido>=1.1.16->pretty_midi) (24.2)

# %%
import pretty_midi
import os

# # Set the input JSON file (adjust path if necessary)
# json_file = 'jsb-chorales-16th.json'

# # Load the chorale data from JSON
# with open(json_file, 'r') as f:
#     data = json.load(f)

# Specify the output folder for MIDI files
output_dir = "midi_outputs"

# Create the folder if it does not exist
os.makedirs(output_dir, exist_ok=True)

# Set a fixed chord duration in seconds; adjust to control the tempo.
chord_duration = 0.5

# Loop through each dataset partition (e.g., 'test', 'train', 'valid')
for subset, chorales in data.items():
    print(f"Processing subset: {subset} with {len(chorales)} chorales...")
    # For each chorale in the current subset...
    for i, chorale in enumerate(chorales):
        # Create a PrettyMIDI object for the current chorale.
        pm = pretty_midi.PrettyMIDI()

        # Create an instrument for each voice (SATB) using a choir patch.
        soprano = pretty_midi.Instrument(program=52)
        alto = pretty_midi.Instrument(program=52)
        tenor = pretty_midi.Instrument(program=52)
        bass = pretty_midi.Instrument(program=52)

        start_time = 0.0  # starting time in seconds

        # Each chord is a list of four numbers [Soprano, Alto, Tenor, Bass]
        for chord in chorale:
            # Ensure there are four elements to unpack.
            if len(chord) < 4:
                continue
            sop_pitch, alt_pitch, ten_pitch, bas_pitch = chord[:4]

            # Cast the pitches to int if they are not already
            sop_pitch = int(sop_pitch)
            alt_pitch = int(alt_pitch)
            ten_pitch = int(ten_pitch)
            bas_pitch = int(bas_pitch)

            # Create a note for each voice.
            sop_note = pretty_midi.Note(velocity=100, pitch=sop_pitch,
                                        start=start_time, end=start_time + chord_duration)
            alt_note = pretty_midi.Note(velocity=100, pitch=alt_pitch,
                                        start=start_time, end=start_time + chord_duration)
            ten_note = pretty_midi.Note(velocity=100, pitch=ten_pitch,
                                        start=start_time, end=start_time + chord_duration)
            bas_note = pretty_midi.Note(velocity=100, pitch=bas_pitch,
                                        start=start_time, end=start_time + chord_duration)

            # Add the notes to the respective instruments.
            soprano.notes.append(sop_note)
            alto.notes.append(alt_note)
            tenor.notes.append(ten_note)
            bass.notes.append(bas_note)

            # Advance the time by the chord duration.
            start_time += chord_duration

        # Add the instruments to the PrettyMIDI object.
        pm.instruments.extend([soprano, alto, tenor, bass])

        # Construct a filename such as "test_chorale_0.mid"
        midi_filename = os.path.join(output_dir, f"{subset}_chorale_{i}.mid")
        pm.write(midi_filename)
        print(f"Written {midi_filename}")

print("All MIDI files have been created and placed in the folder:", output_dir)
# Out:
# Processing subset: test with 77 chorales...
# Written midi_outputs/test_chorale_0.mid
# Written midi_outputs/test_chorale_1.mid
# Written midi_outputs/test_chorale_2.mid
# Written midi_outputs/test_chorale_3.mid
# Written midi_outputs/test_chorale_4.mid
# Written midi_outputs/test_chorale_5.mid
# Written midi_outputs/test_chorale_6.mid
# Written midi_outputs/test_chorale_7.mid
# Written midi_outputs/test_chorale_8.mid
# Written midi_outputs/test_chorale_9.mid
# Written midi_outputs/test_chorale_10.mid
# Written midi_outputs/test_chorale_11.mid
# Written midi_outputs/test_chorale_12.mid
# Written midi_outputs/test_chorale_13.mid
# Written midi_outputs/test_chorale_14.mid
# Written midi_outputs/test_chorale_15.mid
# Written midi_outputs/test_chorale_16.mid
# Written midi_outputs/test_chorale_17.mid
# Written midi_outputs/test_chorale_18.mid
# Written midi_outputs/test_chorale_19.mid
# Written midi_outputs/test_chorale_20.mid
# Written midi_outputs/test_chorale_21.mid
# Written midi_outputs/test_chorale_22.mid
# Written midi_outputs/test_chorale_23.mid
# Written midi_outputs/test_chorale_24.mid
# Written midi_outputs/test_chorale_25.mid
# Written midi_outputs/test_chorale_26.mid
# Written midi_outputs/test_chorale_27.mid
# Written midi_outputs/test_chorale_28.mid
# Written midi_outputs/test_chorale_29.mid
# Written midi_outputs/test_chorale_30.mid
# Written midi_outputs/test_chorale_31.mid
# Written midi_outputs/test_chorale_32.mid
# Written midi_outputs/test_chorale_33.mid
# Written midi_outputs/test_chorale_34.mid
# Written midi_outputs/test_chorale_35.mid
# Written midi_outputs/test_chorale_36.mid
# Written midi_outputs/test_chorale_37.mid
# Written midi_outputs/test_chorale_38.mid
# Written midi_outputs/test_chorale_39.mid
# Written midi_outputs/test_chorale_40.mid
# Written midi_outputs/test_chorale_41.mid
# Written midi_outputs/test_chorale_42.mid
# Written midi_outputs/test_chorale_43.mid
# Written midi_outputs/test_chorale_44.mid
# Written midi_outputs/test_chorale_45.mid
# Written midi_outputs/test_chorale_46.mid
# Written midi_outputs/test_chorale_47.mid
# Written midi_outputs/test_chorale_48.mid
# Written midi_outputs/test_chorale_49.mid
# Written midi_outputs/test_chorale_50.mid
# Written midi_outputs/test_chorale_51.mid
# Written midi_outputs/test_chorale_52.mid
# Written midi_outputs/test_chorale_53.mid
# Written midi_outputs/test_chorale_54.mid
# Written midi_outputs/test_chorale_55.mid
# Written midi_outputs/test_chorale_56.mid
# Written midi_outputs/test_chorale_57.mid
# Written midi_outputs/test_chorale_58.mid
# Written midi_outputs/test_chorale_59.mid
# Written midi_outputs/test_chorale_60.mid
# Written midi_outputs/test_chorale_61.mid
# Written midi_outputs/test_chorale_62.mid
# Written midi_outputs/test_chorale_63.mid
# Written midi_outputs/test_chorale_64.mid
# Written midi_outputs/test_chorale_65.mid
# Written midi_outputs/test_chorale_66.mid
# Written midi_outputs/test_chorale_67.mid
# Written midi_outputs/test_chorale_68.mid
# Written midi_outputs/test_chorale_69.mid
# Written midi_outputs/test_chorale_70.mid
# Written midi_outputs/test_chorale_71.mid
# Written midi_outputs/test_chorale_72.mid
# Written midi_outputs/test_chorale_73.mid
# Written midi_outputs/test_chorale_74.mid
# Written midi_outputs/test_chorale_75.mid
# Written midi_outputs/test_chorale_76.mid
# Processing subset: train with 229 chorales...
# Written midi_outputs/train_chorale_0.mid
# Written midi_outputs/train_chorale_1.mid
# Written midi_outputs/train_chorale_2.mid
# Written midi_outputs/train_chorale_3.mid
# Written midi_outputs/train_chorale_4.mid
# Written midi_outputs/train_chorale_5.mid
# Written midi_outputs/train_chorale_6.mid
# Written midi_outputs/train_chorale_7.mid
# Written midi_outputs/train_chorale_8.mid
# Written midi_outputs/train_chorale_9.mid
# Written midi_outputs/train_chorale_10.mid
# Written midi_outputs/train_chorale_11.mid
# Written midi_outputs/train_chorale_12.mid
# Written midi_outputs/train_chorale_13.mid
# Written midi_outputs/train_chorale_14.mid
# Written midi_outputs/train_chorale_15.mid
# Written midi_outputs/train_chorale_16.mid
# Written midi_outputs/train_chorale_17.mid
# Written midi_outputs/train_chorale_18.mid
# Written midi_outputs/train_chorale_19.mid
# Written midi_outputs/train_chorale_20.mid
# Written midi_outputs/train_chorale_21.mid
# Written midi_outputs/train_chorale_22.mid
# Written midi_outputs/train_chorale_23.mid
# Written midi_outputs/train_chorale_24.mid
# Written midi_outputs/train_chorale_25.mid
# Written midi_outputs/train_chorale_26.mid
# Written midi_outputs/train_chorale_27.mid
# Written midi_outputs/train_chorale_28.mid
# Written midi_outputs/train_chorale_29.mid
# Written midi_outputs/train_chorale_30.mid
# Written midi_outputs/train_chorale_31.mid
# Written midi_outputs/train_chorale_32.mid
# Written midi_outputs/train_chorale_33.mid
# Written midi_outputs/train_chorale_34.mid
# Written midi_outputs/train_chorale_35.mid
# Written midi_outputs/train_chorale_36.mid
# Written midi_outputs/train_chorale_37.mid
# Written midi_outputs/train_chorale_38.mid
# Written midi_outputs/train_chorale_39.mid
# Written midi_outputs/train_chorale_40.mid
# Written midi_outputs/train_chorale_41.mid
# Written midi_outputs/train_chorale_42.mid
# Written midi_outputs/train_chorale_43.mid
# Written midi_outputs/train_chorale_44.mid
# Written midi_outputs/train_chorale_45.mid
# Written midi_outputs/train_chorale_46.mid
# Written midi_outputs/train_chorale_47.mid
# Written midi_outputs/train_chorale_48.mid
# Written midi_outputs/train_chorale_49.mid
# Written midi_outputs/train_chorale_50.mid
# Written midi_outputs/train_chorale_51.mid
# Written midi_outputs/train_chorale_52.mid
# Written midi_outputs/train_chorale_53.mid
# Written midi_outputs/train_chorale_54.mid
# Written midi_outputs/train_chorale_55.mid
# Written midi_outputs/train_chorale_56.mid
# Written midi_outputs/train_chorale_57.mid
# Written midi_outputs/train_chorale_58.mid
# Written midi_outputs/train_chorale_59.mid
# Written midi_outputs/train_chorale_60.mid
# Written midi_outputs/train_chorale_61.mid
# Written midi_outputs/train_chorale_62.mid
# Written midi_outputs/train_chorale_63.mid
# Written midi_outputs/train_chorale_64.mid
# Written midi_outputs/train_chorale_65.mid
# Written midi_outputs/train_chorale_66.mid
# Written midi_outputs/train_chorale_67.mid
# Written midi_outputs/train_chorale_68.mid
# Written midi_outputs/train_chorale_69.mid
# Written midi_outputs/train_chorale_70.mid
# Written midi_outputs/train_chorale_71.mid
# Written midi_outputs/train_chorale_72.mid
# Written midi_outputs/train_chorale_73.mid
# Written midi_outputs/train_chorale_74.mid
# Written midi_outputs/train_chorale_75.mid
# Written midi_outputs/train_chorale_76.mid
# Written midi_outputs/train_chorale_77.mid
# Written midi_outputs/train_chorale_78.mid
# Written midi_outputs/train_chorale_79.mid
# Written midi_outputs/train_chorale_80.mid
# Written midi_outputs/train_chorale_81.mid
# Written midi_outputs/train_chorale_82.mid
# Written midi_outputs/train_chorale_83.mid
# Written midi_outputs/train_chorale_84.mid
# Written midi_outputs/train_chorale_85.mid
# Written midi_outputs/train_chorale_86.mid
# Written midi_outputs/train_chorale_87.mid
# Written midi_outputs/train_chorale_88.mid
# Written midi_outputs/train_chorale_89.mid
# Written midi_outputs/train_chorale_90.mid
# Written midi_outputs/train_chorale_91.mid
# Written midi_outputs/train_chorale_92.mid
# Written midi_outputs/train_chorale_93.mid
# Written midi_outputs/train_chorale_94.mid
# Written midi_outputs/train_chorale_95.mid
# Written midi_outputs/train_chorale_96.mid
# Written midi_outputs/train_chorale_97.mid
# Written midi_outputs/train_chorale_98.mid
# Written midi_outputs/train_chorale_99.mid
# Written midi_outputs/train_chorale_100.mid
# Written midi_outputs/train_chorale_101.mid
# Written midi_outputs/train_chorale_102.mid
# Written midi_outputs/train_chorale_103.mid
# Written midi_outputs/train_chorale_104.mid
# Written midi_outputs/train_chorale_105.mid
# Written midi_outputs/train_chorale_106.mid
# Written midi_outputs/train_chorale_107.mid
# Written midi_outputs/train_chorale_108.mid
# Written midi_outputs/train_chorale_109.mid
# Written midi_outputs/train_chorale_110.mid
# Written midi_outputs/train_chorale_111.mid
# Written midi_outputs/train_chorale_112.mid
# Written midi_outputs/train_chorale_113.mid
# Written midi_outputs/train_chorale_114.mid
# Written midi_outputs/train_chorale_115.mid
# Written midi_outputs/train_chorale_116.mid
# Written midi_outputs/train_chorale_117.mid
# Written midi_outputs/train_chorale_118.mid
# Written midi_outputs/train_chorale_119.mid
# Written midi_outputs/train_chorale_120.mid
# Written midi_outputs/train_chorale_121.mid
# Written midi_outputs/train_chorale_122.mid
# Written midi_outputs/train_chorale_123.mid
# Written midi_outputs/train_chorale_124.mid
# Written midi_outputs/train_chorale_125.mid
# Written midi_outputs/train_chorale_126.mid
# Written midi_outputs/train_chorale_127.mid
# Written midi_outputs/train_chorale_128.mid
# Written midi_outputs/train_chorale_129.mid
# Written midi_outputs/train_chorale_130.mid
# Written midi_outputs/train_chorale_131.mid
# Written midi_outputs/train_chorale_132.mid
# Written midi_outputs/train_chorale_133.mid
# Written midi_outputs/train_chorale_134.mid
# Written midi_outputs/train_chorale_135.mid
# Written midi_outputs/train_chorale_136.mid
# Written midi_outputs/train_chorale_137.mid
# Written midi_outputs/train_chorale_138.mid
# Written midi_outputs/train_chorale_139.mid
# Written midi_outputs/train_chorale_140.mid
# Written midi_outputs/train_chorale_141.mid
# Written midi_outputs/train_chorale_142.mid
# Written midi_outputs/train_chorale_143.mid
# Written midi_outputs/train_chorale_144.mid
# Written midi_outputs/train_chorale_145.mid
# Written midi_outputs/train_chorale_146.mid
# Written midi_outputs/train_chorale_147.mid
# Written midi_outputs/train_chorale_148.mid
# Written midi_outputs/train_chorale_149.mid
# Written midi_outputs/train_chorale_150.mid
# Written midi_outputs/train_chorale_151.mid
# Written midi_outputs/train_chorale_152.mid
# Written midi_outputs/train_chorale_153.mid
# Written midi_outputs/train_chorale_154.mid
# Written midi_outputs/train_chorale_155.mid
# Written midi_outputs/train_chorale_156.mid
# Written midi_outputs/train_chorale_157.mid
# Written midi_outputs/train_chorale_158.mid
# Written midi_outputs/train_chorale_159.mid
# Written midi_outputs/train_chorale_160.mid
# Written midi_outputs/train_chorale_161.mid
# Written midi_outputs/train_chorale_162.mid
# Written midi_outputs/train_chorale_163.mid
# Written midi_outputs/train_chorale_164.mid
# Written midi_outputs/train_chorale_165.mid
# Written midi_outputs/train_chorale_166.mid
# Written midi_outputs/train_chorale_167.mid
# Written midi_outputs/train_chorale_168.mid
# Written midi_outputs/train_chorale_169.mid
# Written midi_outputs/train_chorale_170.mid
# Written midi_outputs/train_chorale_171.mid
# Written midi_outputs/train_chorale_172.mid
# Written midi_outputs/train_chorale_173.mid
# Written midi_outputs/train_chorale_174.mid
# Written midi_outputs/train_chorale_175.mid
# Written midi_outputs/train_chorale_176.mid
# Written midi_outputs/train_chorale_177.mid
# Written midi_outputs/train_chorale_178.mid
# Written midi_outputs/train_chorale_179.mid
# Written midi_outputs/train_chorale_180.mid
# Written midi_outputs/train_chorale_181.mid
# Written midi_outputs/train_chorale_182.mid
# Written midi_outputs/train_chorale_183.mid
# Written midi_outputs/train_chorale_184.mid
# Written midi_outputs/train_chorale_185.mid
# Written midi_outputs/train_chorale_186.mid
# Written midi_outputs/train_chorale_187.mid
# Written midi_outputs/train_chorale_188.mid
# Written midi_outputs/train_chorale_189.mid
# Written midi_outputs/train_chorale_190.mid
# Written midi_outputs/train_chorale_191.mid
# Written midi_outputs/train_chorale_192.mid
# Written midi_outputs/train_chorale_193.mid
# Written midi_outputs/train_chorale_194.mid
# Written midi_outputs/train_chorale_195.mid
# Written midi_outputs/train_chorale_196.mid
# Written midi_outputs/train_chorale_197.mid
# Written midi_outputs/train_chorale_198.mid
# Written midi_outputs/train_chorale_199.mid
# Written midi_outputs/train_chorale_200.mid
# Written midi_outputs/train_chorale_201.mid
# Written midi_outputs/train_chorale_202.mid
# Written midi_outputs/train_chorale_203.mid
# Written midi_outputs/train_chorale_204.mid
# Written midi_outputs/train_chorale_205.mid
# Written midi_outputs/train_chorale_206.mid
# Written midi_outputs/train_chorale_207.mid
# Written midi_outputs/train_chorale_208.mid
# Written midi_outputs/train_chorale_209.mid
# Written midi_outputs/train_chorale_210.mid
# Written midi_outputs/train_chorale_211.mid
# Written midi_outputs/train_chorale_212.mid
# Written midi_outputs/train_chorale_213.mid
# Written midi_outputs/train_chorale_214.mid
# Written midi_outputs/train_chorale_215.mid
# Written midi_outputs/train_chorale_216.mid
# Written midi_outputs/train_chorale_217.mid
# Written midi_outputs/train_chorale_218.mid
# Written midi_outputs/train_chorale_219.mid
# Written midi_outputs/train_chorale_220.mid
# Written midi_outputs/train_chorale_221.mid
# Written midi_outputs/train_chorale_222.mid
# Written midi_outputs/train_chorale_223.mid
# Written midi_outputs/train_chorale_224.mid
# Written midi_outputs/train_chorale_225.mid
# Written midi_outputs/train_chorale_226.mid
# Written midi_outputs/train_chorale_227.mid
# Written midi_outputs/train_chorale_228.mid
# Processing subset: valid with 76 chorales...
# Written midi_outputs/valid_chorale_0.mid
# Written midi_outputs/valid_chorale_1.mid
# Written midi_outputs/valid_chorale_2.mid
# Written midi_outputs/valid_chorale_3.mid
# Written midi_outputs/valid_chorale_4.mid
# Written midi_outputs/valid_chorale_5.mid
# Written midi_outputs/valid_chorale_6.mid
# Written midi_outputs/valid_chorale_7.mid
# Written midi_outputs/valid_chorale_8.mid
# Written midi_outputs/valid_chorale_9.mid
# Written midi_outputs/valid_chorale_10.mid
# Written midi_outputs/valid_chorale_11.mid
# Written midi_outputs/valid_chorale_12.mid
# Written midi_outputs/valid_chorale_13.mid
# Written midi_outputs/valid_chorale_14.mid
# Written midi_outputs/valid_chorale_15.mid
# Written midi_outputs/valid_chorale_16.mid
# Written midi_outputs/valid_chorale_17.mid
# Written midi_outputs/valid_chorale_18.mid
# Written midi_outputs/valid_chorale_19.mid
# Written midi_outputs/valid_chorale_20.mid
# Written midi_outputs/valid_chorale_21.mid
# Written midi_outputs/valid_chorale_22.mid
# Written midi_outputs/valid_chorale_23.mid
# Written midi_outputs/valid_chorale_24.mid
# Written midi_outputs/valid_chorale_25.mid
# Written midi_outputs/valid_chorale_26.mid
# Written midi_outputs/valid_chorale_27.mid
# Written midi_outputs/valid_chorale_28.mid
# Written midi_outputs/valid_chorale_29.mid
# Written midi_outputs/valid_chorale_30.mid
# Written midi_outputs/valid_chorale_31.mid
# Written midi_outputs/valid_chorale_32.mid
# Written midi_outputs/valid_chorale_33.mid
# Written midi_outputs/valid_chorale_34.mid
# Written midi_outputs/valid_chorale_35.mid
# Written midi_outputs/valid_chorale_36.mid
# Written midi_outputs/valid_chorale_37.mid
# Written midi_outputs/valid_chorale_38.mid
# Written midi_outputs/valid_chorale_39.mid
# Written midi_outputs/valid_chorale_40.mid
# Written midi_outputs/valid_chorale_41.mid
# Written midi_outputs/valid_chorale_42.mid
# Written midi_outputs/valid_chorale_43.mid
# Written midi_outputs/valid_chorale_44.mid
# Written midi_outputs/valid_chorale_45.mid
# Written midi_outputs/valid_chorale_46.mid
# Written midi_outputs/valid_chorale_47.mid
# Written midi_outputs/valid_chorale_48.mid
# Written midi_outputs/valid_chorale_49.mid
# Written midi_outputs/valid_chorale_50.mid
# Written midi_outputs/valid_chorale_51.mid
# Written midi_outputs/valid_chorale_52.mid
# Written midi_outputs/valid_chorale_53.mid
# Written midi_outputs/valid_chorale_54.mid
# Written midi_outputs/valid_chorale_55.mid
# Written midi_outputs/valid_chorale_56.mid
# Written midi_outputs/valid_chorale_57.mid
# Written midi_outputs/valid_chorale_58.mid
# Written midi_outputs/valid_chorale_59.mid
# Written midi_outputs/valid_chorale_60.mid
# Written midi_outputs/valid_chorale_61.mid
# Written midi_outputs/valid_chorale_62.mid
# Written midi_outputs/valid_chorale_63.mid
# Written midi_outputs/valid_chorale_64.mid
# Written midi_outputs/valid_chorale_65.mid
# Written midi_outputs/valid_chorale_66.mid
# Written midi_outputs/valid_chorale_67.mid
# Written midi_outputs/valid_chorale_68.mid
# Written midi_outputs/valid_chorale_69.mid
# Written midi_outputs/valid_chorale_70.mid
# Written midi_outputs/valid_chorale_71.mid
# Written midi_outputs/valid_chorale_72.mid
# Written midi_outputs/valid_chorale_73.mid
# Written midi_outputs/valid_chorale_74.mid
# Written midi_outputs/valid_chorale_75.mid
# Processing subset: 0 with 0 chorales...
# All MIDI files have been created and placed in the folder: midi_outputs

# %%
import os
import random
import pretty_midi
import matplotlib.pyplot as plt

# Specify the folder where your MIDI files are stored.
midi_folder = "/Users/cui/Documents/GitHub/MIDI-Harmonization-LCZS/midi_outputs"

# Get all MIDI files in the folder.
midi_files = [f for f in os.listdir(midi_folder) if f.lower().endswith(".mid")]

if not midi_files:
    raise FileNotFoundError("No MIDI files found in the specified folder.")

# Randomly choose one MIDI file.
selected_file = random.choice(midi_files)
file_path = os.path.join(midi_folder, selected_file)
print(f"Selected MIDI file: {selected_file}")

# Load the selected MIDI file with PrettyMIDI.
pm = pretty_midi.PrettyMIDI(file_path)

# Generate a piano roll for visualization.
# fs sets the frame rate; adjust if necessary.
piano_roll = pm.get_piano_roll(fs=100)

# Plot the piano roll.
plt.figure(figsize=(12, 6))
plt.imshow(piano_roll, aspect="auto", origin="lower", cmap="gray_r")
plt.xlabel("Time Frames")
plt.ylabel("MIDI Pitch")
plt.title(f"Piano Roll Visualization of {selected_file}")
plt.colorbar(label="Velocity")
plt.show()
# Out:
# Selected MIDI file: train_chorale_226.mid

# %%
import json

# Load the raw JSON file from JSB Chorales dataset.
with open("/Users/cui/Documents/GitHub/MIDI-Harmonization-LCZS/JSB-Chorales-dataset-master/jsb-chorales-16th.json", "r") as file:
    data = json.load(file)

# Assuming the dataset is stored under the key "test"
chorales = data["test"]

# Prepare lists to hold the separated parts
soprano_voices = []  # S part for each chorale
atb_parts = []       # Combined ATB parts for each chorale

# Iterate through each chorale (each chorale is a paragraph)
for chorale in chorales:
    s_voice = []  # Collect Soprano notes for this chorale
    atb = []      # Collect Alto, Tenor, Bass notes for this chorale
    for timestep in chorale:
        if len(timestep) >= 4:
            s_voice.append(timestep[0])      # First element: Soprano
            atb.append(timestep[1:4])          # Next three: ATB
    soprano_voices.append(s_voice)
    atb_parts.append(atb)

# Save the separated parts as JSON files
with open("soprano_voices.json", "w") as s_file:
    json.dump(soprano_voices, s_file, indent=2)

with open("atb_parts.json", "w") as atb_file:
    json.dump(atb_parts, atb_file, indent=2)

print("Files 'soprano_voices.json' and 'atb_parts.json' have been created successfully.")
# Out:
# Files 'soprano_voices.json' and 'atb_parts.json' have been created successfully.

# %%
import os
import json

# Load previously created JSON files.
with open("/Users/cui/Documents/GitHub/MIDI-Harmonization-LCZS/soprano_voices.json", "r") as sp_file:
    soprano_data = json.load(sp_file)

with open("/Users/cui/Documents/GitHub/MIDI-Harmonization-LCZS/atb_parts.json", "r") as atb_file:
    atb_data = json.load(atb_file)

# Create directories to hold per-chorale paragraphs if they don't exist.
soprano_folder = "soprano_paragraphs"
atb_folder = "atb_paragraphs"
os.makedirs(soprano_folder, exist_ok=True)
os.makedirs(atb_folder, exist_ok=True)

# Write each paragraph (chorale) into a separate JSON file.
for i, paragraph in enumerate(soprano_data, start=1):
    filename = os.path.join(soprano_folder, f"paragraph_{i}.json")
    with open(filename, "w") as f:
        json.dump(paragraph, f, indent=2)

for i, paragraph in enumerate(atb_data, start=1):
    filename = os.path.join(atb_folder, f"paragraph_{i}.json")
    with open(filename, "w") as f:
        json.dump(paragraph, f, indent=2)

print("Paragraph files have been created in 'soprano_paragraphs' and 'atb_paragraphs'.")
# Out:
# Paragraph files have been created in 'soprano_paragraphs' and 'atb_paragraphs'.

# %%
import os
import json
import torch
from torch.utils.data import Dataset, DataLoader, random_split
from torch.nn.utils.rnn import pad_sequence

class ChoraleDataset(Dataset):
    def __init__(self, soprano_folder, atb_folder):
        # List JSON files in the folders and sort (to ensure alignment)
        self.soprano_files = sorted([os.path.join(soprano_folder, f) 
                                     for f in os.listdir(soprano_folder) if f.endswith('.json')])
        self.atb_files = sorted([os.path.join(atb_folder, f) 
                                 for f in os.listdir(atb_folder) if f.endswith('.json')])
        assert len(self.soprano_files) == len(self.atb_files), "Mismatch between soprano and atb files."
    
    def __len__(self):
        return len(self.soprano_files)
    
    def __getitem__(self, idx):
        with open(self.soprano_files[idx], 'r') as f:
            soprano = json.load(f)
        with open(self.atb_files[idx], 'r') as f:
            atb = json.load(f)
        # Convert lists to tensors
        soprano_tensor = torch.tensor(soprano, dtype=torch.long)
        atb_tensor = torch.tensor(atb, dtype=torch.long)  # Expected shape: [seq_length, 3]
        return {'soprano': soprano_tensor, 'atb': atb_tensor}

def collate_fn(batch):
    sopranos = [sample['soprano'] for sample in batch]
    atbs = [sample['atb'] for sample in batch]
    padded_soprano = pad_sequence(sopranos, batch_first=True, padding_value=0)
    padded_atb = pad_sequence(atbs, batch_first=True, padding_value=0)
    return {'soprano': padded_soprano, 'atb': padded_atb}

# Create the dataset instance.
dataset = ChoraleDataset("soprano_paragraphs", "atb_paragraphs")
print(f"Total paragraphs (samples): {len(dataset)}")
# Out:
# Total paragraphs (samples): 77

# %%
from torch.utils.data import random_split

total_size = len(dataset)
test_size = int(0.05 * total_size)
val_size = int(0.20 * total_size)
train_size = total_size - val_size - test_size

train_dataset, val_dataset, test_dataset = random_split(dataset, [train_size, val_size, test_size])

train_dataloader = DataLoader(train_dataset, batch_size=4, shuffle=True, collate_fn=collate_fn)
val_dataloader = DataLoader(val_dataset, batch_size=4, shuffle=False, collate_fn=collate_fn)
test_dataloader = DataLoader(test_dataset, batch_size=4, shuffle=False, collate_fn=collate_fn)

print(f"Train samples: {len(train_dataset)}, Validation samples: {len(val_dataset)}, Test samples: {len(test_dataset)}")
# Out:
# Train samples: 59, Validation samples: 15, Test samples: 3

# %%
import torch
import torch.nn as nn
import torch.optim as optim

# Define special tokens.
PAD_TOKEN = 0
SOS_TOKEN = 128  # Assumes valid MIDI notes are in 0-127.
INPUT_VOCAB_SIZE = 129   # 0..128
OUTPUT_VOCAB_SIZE = 129  # same for ATB voices
EMBED_DIM = 64
HIDDEN_SIZE = 128
NUM_LAYERS = 1
TEACHER_FORCING_RATIO = 0.5
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# ----- Encoder -----
class Encoder(nn.Module):
    def __init__(self, input_vocab_size, embed_dim, hidden_size, num_layers=1):
        super(Encoder, self).__init__()
        self.embedding = nn.Embedding(input_vocab_size, embed_dim)
        self.lstm = nn.LSTM(embed_dim, hidden_size, num_layers, batch_first=True)
    
    def forward(self, input_seq):
        embedded = self.embedding(input_seq)  # [batch_size, seq_len, embed_dim]
        outputs, (hidden, cell) = self.lstm(embedded)
        return hidden, cell

# ----- Decoder -----
class Decoder(nn.Module):
    def __init__(self, output_vocab_size, embed_dim, hidden_size, num_layers=1):
        super(Decoder, self).__init__()
        # Separate embeddings for Alto, Tenor, Bass.
        self.embed_alto = nn.Embedding(output_vocab_size, embed_dim)
        self.embed_tenor = nn.Embedding(output_vocab_size, embed_dim)
        self.embed_bass = nn.Embedding(output_vocab_size, embed_dim)
        # LSTM takes a concatenated embedding (3 * embed_dim)
        self.lstm = nn.LSTM(3 * embed_dim, hidden_size, num_layers, batch_first=True)
        # Separate linear layers for each voice.
        self.fc_alto = nn.Linear(hidden_size, output_vocab_size)
        self.fc_tenor = nn.Linear(hidden_size, output_vocab_size)
        self.fc_bass = nn.Linear(hidden_size, output_vocab_size)
    
    def forward(self, input_triple, hidden, cell):
        # Each input token is of shape [batch_size]; add time dimension.
        alto = input_triple[0].unsqueeze(1)
        tenor = input_triple[1].unsqueeze(1)
        bass = input_triple[2].unsqueeze(1)
        emb_alto = self.embed_alto(alto)
        emb_tenor = self.embed_tenor(tenor)
        emb_bass = self.embed_bass(bass)
        # Concatenate embeddings along last dimension.
        combined = torch.cat([emb_alto, emb_tenor, emb_bass], dim=2)
        output, (hidden, cell) = self.lstm(combined, (hidden, cell))
        alto_pred = self.fc_alto(output.squeeze(1))
        tenor_pred = self.fc_tenor(output.squeeze(1))
        bass_pred = self.fc_bass(output.squeeze(1))
        return (alto_pred, tenor_pred, bass_pred), hidden, cell

class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super(Seq2Seq, self).__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device

    def forward(self, src, trg, teacher_forcing_ratio=0.5):
        batch_size = src.size(0)
        trg_len = trg.size(1)
        output_vocab_size = self.decoder.fc_alto.out_features
        
        outputs_alto = torch.zeros(batch_size, trg_len, output_vocab_size).to(self.device)
        outputs_tenor = torch.zeros(batch_size, trg_len, output_vocab_size).to(self.device)
        outputs_bass = torch.zeros(batch_size, trg_len, output_vocab_size).to(self.device)
        
        hidden, cell = self.encoder(src)
        
        input_alto = torch.full((batch_size,), SOS_TOKEN, dtype=torch.long).to(self.device)
        input_tenor = torch.full((batch_size,), SOS_TOKEN, dtype=torch.long).to(self.device)
        input_bass  = torch.full((batch_size,), SOS_TOKEN, dtype=torch.long).to(self.device)
        
        for t in range(trg_len):
            output, hidden, cell = self.decoder((input_alto, input_tenor, input_bass), hidden, cell)
            alto_pred, tenor_pred, bass_pred = output
            outputs_alto[:, t, :] = alto_pred
            outputs_tenor[:, t, :] = tenor_pred
            outputs_bass[:, t, :] = bass_pred
            
            # Here we compute teacher forcing decision per time step.
            # You might implement a scheduled teacher forcing ratio (for example, reducing it over epochs).
            teacher_force = (torch.rand(1).item() < teacher_forcing_ratio)
            
            target_tokens = trg[:, t, :]  # [batch_size, 3]
            if teacher_force:
                # Use the ground-truth tokens.
                input_alto = target_tokens[:, 0]
                input_tenor = target_tokens[:, 1]
                input_bass = target_tokens[:, 2]
            else:
                # Otherwise, feed in the model's own predictions.
                input_alto = alto_pred.argmax(dim=1)
                input_tenor = tenor_pred.argmax(dim=1)
                input_bass = bass_pred.argmax(dim=1)
        
        return outputs_alto, outputs_tenor, outputs_bass

# Initialize model, optimizer, and criterion.
encoder = Encoder(INPUT_VOCAB_SIZE, EMBED_DIM, HIDDEN_SIZE, NUM_LAYERS).to(DEVICE)
decoder = Decoder(OUTPUT_VOCAB_SIZE, EMBED_DIM, HIDDEN_SIZE, NUM_LAYERS).to(DEVICE)
model = Seq2Seq(encoder, decoder, DEVICE).to(DEVICE)

optimizer = optim.Adam(model.parameters(), lr=0.001)
# Use ignore_index for PAD tokens in loss.
criterion = nn.CrossEntropyLoss(ignore_index=PAD_TOKEN)

# %%
num_epochs = 10
for epoch in range(num_epochs):
    model.train()
    epoch_loss = 0
    for batch in train_dataloader:
        src = batch['soprano'].to(DEVICE)       # [batch_size, seq_len]
        trg = batch['atb'].to(DEVICE)             # [batch_size, seq_len, 3]
        
        optimizer.zero_grad()
        outputs_alto, outputs_tenor, outputs_bass = model(src, trg, teacher_forcing_ratio=TEACHER_FORCING_RATIO)
        
        batch_size, seq_len, vocab_size = outputs_alto.shape
        out_alto = outputs_alto.reshape(-1, vocab_size)
        out_tenor = outputs_tenor.reshape(-1, vocab_size)
        out_bass = outputs_bass.reshape(-1, vocab_size)
        
        trg_alto = trg[:, :, 0].reshape(-1)
        trg_tenor = trg[:, :, 1].reshape(-1)
        trg_bass = trg[:, :, 2].reshape(-1)
        
        loss_alto = criterion(out_alto, trg_alto)
        loss_tenor = criterion(out_tenor, trg_tenor)
        loss_bass = criterion(out_bass, trg_bass)
        loss = loss_alto + loss_tenor + loss_bass
        
        loss.backward()
        optimizer.step()
        epoch_loss += loss.item()
    
    print(f"Epoch {epoch+1}/{num_epochs} Loss: {epoch_loss/len(train_dataloader):.4f}")
# Out:
# Epoch 1/10 Loss: 13.1028
# Epoch 2/10 Loss: 8.5553
# Epoch 3/10 Loss: 7.4748
# Epoch 4/10 Loss: 7.0679
# Epoch 5/10 Loss: 6.6718
# Epoch 6/10 Loss: 6.3616
# Epoch 7/10 Loss: 6.0878
# Epoch 8/10 Loss: 5.8771
# Epoch 9/10 Loss: 5.7027
# Epoch 10/10 Loss: 5.4993

# %%
def evaluate(model, dataloader, criterion, device):
    model.eval()
    total_loss_alto = 0
    total_loss_tenor = 0
    total_loss_bass = 0
    total_batches = 0

    with torch.no_grad():
        for batch in dataloader:
            src = batch['soprano'].to(device)     # [batch_size, seq_len]
            trg = batch['atb'].to(device)           # [batch_size, seq_len, 3]
            outputs_alto, outputs_tenor, outputs_bass = model(src, trg, teacher_forcing_ratio=0.0)
            batch_size, seq_len, vocab_size = outputs_alto.shape
            out_alto = outputs_alto.reshape(-1, vocab_size)
            out_tenor = outputs_tenor.reshape(-1, vocab_size)
            out_bass = outputs_bass.reshape(-1, vocab_size)
            trg_alto = trg[:, :, 0].reshape(-1)
            trg_tenor = trg[:, :, 1].reshape(-1)
            trg_bass = trg[:, :, 2].reshape(-1)
            loss_alto = criterion(out_alto, trg_alto)
            loss_tenor = criterion(out_tenor, trg_tenor)
            loss_bass = criterion(out_bass, trg_bass)
            total_loss_alto += loss_alto.item()
            total_loss_tenor += loss_tenor.item()
            total_loss_bass += loss_bass.item()
            total_batches += 1

    avg_loss_alto = total_loss_alto / total_batches
    avg_loss_tenor = total_loss_tenor / total_batches
    avg_loss_bass = total_loss_bass / total_batches
    print(f"Validation Loss - Alto: {avg_loss_alto:.4f}, Tenor: {avg_loss_tenor:.4f}, Bass: {avg_loss_bass:.4f}")
    return avg_loss_alto, avg_loss_tenor, avg_loss_bass

evaluate(model, val_dataloader, criterion, DEVICE)
# Out:
# Validation Loss - Alto: 2.8691, Tenor: 2.7939, Bass: 2.9578
# (2.869093418121338, 2.793913722038269, 2.9578107595443726)

# %%
model.eval()
all_satb = []  # List to hold SATB sequences for all test samples

with torch.no_grad():
    for batch in test_dataloader:
        src = batch['soprano'].to(DEVICE)   # [batch_size, seq_len]
        trg = batch['atb'].to(DEVICE)         # [batch_size, seq_len, 3]
        outputs_alto, outputs_tenor, outputs_bass = model(src, trg, teacher_forcing_ratio=0.0)
        pred_alto = outputs_alto.argmax(dim=2)  # [batch_size, seq_len]
        pred_tenor = outputs_tenor.argmax(dim=2)
        pred_bass = outputs_bass.argmax(dim=2)
        for i in range(src.size(0)):
            soprano_seq = src[i].cpu().tolist()   # S part
            alto_seq = pred_alto[i].cpu().tolist()
            tenor_seq = pred_tenor[i].cpu().tolist()
            bass_seq = pred_bass[i].cpu().tolist()
            satb = []
            for t in range(len(soprano_seq)):
                satb.append([soprano_seq[t], alto_seq[t], tenor_seq[t], bass_seq[t]])
            all_satb.append(satb)

with open("satb_predictions.json", "w") as f:
    json.dump(all_satb, f, indent=2)

print("SATB predictions have been saved to 'satb_predictions.json'.")
# Out:
# SATB predictions have been saved to 'satb_predictions.json'.

# %%
import json
from music21 import note, stream

# Load SATB predictions
with open("satb_predictions.json", "r") as f:
    satb_data = json.load(f)

# Use the first SATB sample for demonstration.
first_sample = satb_data[0]

# Create four music21 parts for Soprano, Alto, Tenor, and Bass.
soprano_part = stream.Part(id="Soprano")
alto_part = stream.Part(id="Alto")
tenor_part = stream.Part(id="Tenor")
bass_part = stream.Part(id="Bass")

for chord_vals in first_sample:
    s_note = note.Note()
    s_note.pitch.midi = chord_vals[0]
    s_note.quarterLength = 1

    a_note = note.Note()
    a_note.pitch.midi = chord_vals[1]
    a_note.quarterLength = 1

    t_note = note.Note()
    t_note.pitch.midi = chord_vals[2]
    t_note.quarterLength = 1

    b_note = note.Note()
    b_note.pitch.midi = chord_vals[3]
    b_note.quarterLength = 1

    soprano_part.append(s_note)
    alto_part.append(a_note)
    tenor_part.append(t_note)
    bass_part.append(b_note)

score = stream.Score([soprano_part, alto_part, tenor_part, bass_part])
score.write("midi", fp="satb_sample.mid")
print("MIDI file 'satb_sample.mid' has been created.")

# Visualize the generated score.
score.show()
# Out:
# MIDI file 'satb_sample.mid' has been created.
# ---------------------------------------------------------------------------
# SubConverterException                     Traceback (most recent call last)
# Cell In[9], line 44
#      41 print("MIDI file 'satb_sample.mid' has been created.")
#      43 # Visualize the generated score.
# ---> 44 score.show()
#
# File /opt/anaconda3/envs/sb/lib/python3.10/site-packages/music21/stream/base.py:412, in Stream.show(self, fmt, app, **keywords)
#     410 if self.isSorted is False and self.autoSort:
#     411     self.sort()
# --> 412 return super().show(fmt=fmt, app=app, **keywords)
#
# File /opt/anaconda3/envs/sb/lib/python3.10/site-packages/music21/base.py:2996, in Music21Object.show(self, fmt, app, **keywords)
#    2994 scClass = common.findSubConverterForFormat(regularizedConverterFormat)
#    2995 formatWriter = scClass()
# -> 2996 return formatWriter.show(self,
#    2997                          regularizedConverterFormat,
#    2998                          app=app,
#    2999                          subformats=subformats,
#    3000                          **keywords)
#
# File /opt/anaconda3/envs/sb/lib/python3.10/site-packages/music21/converter/subConverters.py:383, in ConverterIPython.show(self, obj, fmt, app, subformats, **keywords)
#     380 helperSubConverter = Converter.getSubConverterFromFormat(helperFormat)
#     382 if helperFormat in ('musicxml', 'xml', 'lilypond', 'lily'):
# --> 383     ip21_converters.showImageThroughMuseScore(
#     384         obj,
#     385         subConverter=helperSubConverter,
#     386         fmt=helperFormat,
#     387         subformats=helperSubformats,
#     388         **keywords,
#     389     )
#     390 elif helperFormat == 'midi':
#     391     if t.TYPE_CHECKING:
#
# File /opt/anaconda3/envs/sb/lib/python3.10/site-packages/music21/ipython21/converters.py:80, in showImageThroughMuseScore(obj, subConverter, fmt, subformats, multipageWidget, **keywords)
#      70         showImageThroughMuseScore(
#      71             s,
#      72             subConverter=subConverter,
#    (...)
#      76             **keywords,
#      77         )
#      78     return
# ---> 80 fp = subConverter.write(
#      81     obj,
#      82     fmt,
#      83     subformats=subformats,
#      84     trimEdges=not multipageWidget,
#      85     **keywords,
#      86 )
#      88 if subformats[0] != 'png':
#      89     return
#
# File /opt/anaconda3/envs/sb/lib/python3.10/site-packages/music21/converter/subConverters.py:991, in ConverterMusicXML.write(self, obj, fmt, fp, subformats, makeNotation, compress, **keywords)
#     988 if (('png' in subformats or 'pdf' in subformats)
#     989         and not str(environLocal['musescoreDirectPNGPath']).startswith('/skip')):
#     990     from music21.converter.museScore import runThroughMuseScore
# --> 991     outFp = runThroughMuseScore(xmlFp, subformats, **keywords)
#     992 elif compress:
#     993     archiveTools.compressXML(xmlFp,
#     994                              deleteOriginal=True,
#     995                              silent=True,
#     996                              strictMxlCheck=False)
#
# File /opt/anaconda3/envs/sb/lib/python3.10/site-packages/music21/converter/museScore.py:55, in runThroughMuseScore(fp, subformats, dpi, trimEdges, leaveMargin, **keywords)
#      51     raise SubConverterException(
#      52         'To create PNG files directly from MusicXML you need to download MuseScore and '
#      53         + 'put a link to it in your .music21rc via Environment.')
#      54 if not museScorePath.exists():
# ---> 55     raise SubConverterException(
#      56         "Cannot find a path to the 'mscore' file at "
#      57         + f'{museScorePath} -- download MuseScore')
#      59 if not subformats:
#      60     subformatExtension = 'png'
#
# SubConverterException: Cannot find a path to the 'mscore' file at /Applications/MuseScore 3.app/Contents/MacOS/mscore -- download MuseScore

# %%
#!/usr/bin/env python
import torch
import random
from methon1 import TransformerHarmonizer, build_model, DEVICE, SOS_TOKEN

def debug_scheduled_sampling(model, src, trg, teacher_forcing_ratio=0.5):
    """
    调试 scheduled sampling 分支下的生成过程，
    每一步打印当前 decoder 的输出 logits、是否采用教师 forcing、
    以及更新后的 decoder 输入序列（ys）的变化。
    """
    model.eval()
    src = src.to(DEVICE)
    trg = trg.to(DEVICE)
    with torch.no_grad():
        # 编码 source 序列
        src_emb = model.src_embedding(src).transpose(0, 1)  # [src_len, batch, d_model]
        memory = model.transformer.encoder(src_emb)
        batch_size, trg_len, _ = trg.shape
        # 以 SOS 三元组开始
        ys = torch.full((batch_size, 1, 3), SOS_TOKEN, dtype=torch.long, device=src.device)
        print("初始输入 (SOS):")
        print(ys)
        # 逐步生成解码序列
        for t in range(trg_len):
            # 获取当前 ys 的嵌入表示，并构造 mask
            tgt_emb = model.tgt_embedding(ys).transpose(0, 1)  # [当前长度, batch, d_model]
            current_len = tgt_emb.size(0)
            current_mask = model.generate_square_subsequent_mask(current_len).to(src.device)
            out = model.transformer.decoder(tgt_emb, memory, tgt_mask=current_mask)
            out = out.transpose(0, 1)  # [batch, 当前长度, d_model]
            last_out = out[:, -1, :]   # 当前时间步输出 [batch, d_model]
            # 得到三个声部的 logits
            curr_alto = model.fc_alto(last_out)    # [batch, vocab_size]
            curr_tenor = model.fc_tenor(last_out)
            curr_bass = model.fc_bass(last_out)
            
            print(f"\n时间步 {t+1}:")
            print("  Logits Alto:")
            print(curr_alto)
            print("  Logits Tenor:")
            print(curr_tenor)
            print("  Logits Bass:")
            print(curr_bass)
            
            # 随机决定是否使用教师 forcing
            use_teacher = (torch.rand(1).item() < teacher_forcing_ratio)
            print("  是否使用教师 forcing:", use_teacher)
            if use_teacher:
                # 使用 ground truth（当前时间步的目标和弦）
                next_input = trg[:, t:t+1, :]
                print("  使用目标输入 (Ground Truth):")
                print(next_input)
            else:
                # 使用模型当前的预测（对各个声部取 argmax）
                pred_alto = curr_alto.argmax(dim=1, keepdim=True)  # [batch, 1]
                pred_tenor = curr_tenor.argmax(dim=1, keepdim=True)
                pred_bass = curr_bass.argmax(dim=1, keepdim=True)
                next_input = torch.cat([pred_alto, pred_tenor, pred_bass], dim=1).unsqueeze(1)  # [batch, 1, 3]
                print("  使用模型预测:")
                print(next_input)
            # 更新 decoder 输入序列
            ys = torch.cat([ys, next_input], dim=1)
            print("  更新后的 ys:")
            print(ys)
    return ys

if __name__ == "__main__":
    # 加载模型（确保 methon1.py 中的 build_model 函数已正确构造模型）
    model, optimizer, criterion = build_model()
    
    # 构造一个简单的样例输入（这里 batch_size=1，序列长度设为 10）
    # 注意：soprano 的 token 范围应在 [1,127]，0 保留为 PAD；这里 SOS_TOKEN 已定义为 128
    src_sample = torch.tensor([[random.randint(1, 127) for _ in range(10)]], dtype=torch.long)
    # 构造目标 ATB 序列，每个时间步一个 3 元组，随机生成（可根据实际情况调整）
    trg_sample = torch.tensor([[[random.randint(1, 127) for _ in range(3)] for _ in range(10)]], dtype=torch.long)
    
    print("Soprano 输入样例:")
    print(src_sample)
    print("目标 ATB 样例:")
    print(trg_sample)
    
    # 调用调试函数
    generated_seq = debug_scheduled_sampling(model, src_sample, trg_sample, teacher_forcing_ratio=0.5)
    
    print("\n最终生成的序列:")
    print(generated_seq)
# Out:
# Soprano 输入样例:
# tensor([[64, 90, 18, 33, 53, 50, 63, 40, 98, 10]])
# 目标 ATB 样例:
# tensor([[[ 24,  37,  47],
#          [ 93,  94,  65],
#          [110,  64,  85],
#          [ 10,  37,  97],
#          [ 38,  44, 118],
#          [101, 105,  57],
#          [ 37,  46, 121],
#          [112,  82,  18],
#          [111, 116, 120],
#          [ 26,  82,  24]]])
# 初始输入 (SOS):
# tensor([[[128, 128, 128]]])
#
# 时间步 1:
#   Logits Alto:
# tensor([[-2.3450e-01,  9.0450e-01,  1.0469e+00,  9.0915e-01,  1.1456e+00,
#           6.6423e-01,  4.5071e-01, -1.0622e+00,  5.5123e-01,  5.1088e-01,
#           2.9986e-01,  1.8889e-01, -4.8090e-01, -5.1650e-01,  5.1727e-01,
#          -6.1059e-01, -1.2300e-01,  3.1997e-01, -3.8587e-01,  2.2120e-01,
#           2.6203e-01, -7.1416e-01,  7.8833e-01, -8.5715e-01,  6.8438e-01,
#          -4.5570e-01, -5.3201e-01,  1.2078e-01,  1.6456e-01,  6.8157e-02,
#          -2.4828e-01, -5.4906e-01, -8.7706e-01, -2.6046e-01, -1.4504e-02,
#           5.4718e-01, -3.3342e-01,  5.4886e-01, -4.1623e-01, -7.8687e-02,
#          -1.0493e-01,  3.3847e-01, -1.9823e-01, -4.1863e-01, -9.4913e-01,
#           1.0914e-01, -5.3619e-01,  8.6257e-02,  3.8022e-01, -3.2545e-02,
#           5.8905e-01,  1.3420e-01, -1.4256e+00, -6.9167e-01,  4.1252e-01,
#           9.7749e-02, -1.6150e-01, -5.6367e-01,  4.9536e-01,  6.9775e-01,
#           3.3869e-01,  3.9958e-01, -9.3695e-01, -8.4291e-01,  5.1363e-02,
#           5.3126e-02,  4.5825e-01, -8.0493e-01, -1.2821e+00, -9.9459e-01,
#           4.2783e-01, -5.4277e-01,  6.4136e-02, -8.5859e-01,  4.5148e-01,
#           3.7371e-01,  6.5768e-04, -7.9952e-01, -1.1811e-01,  6.1696e-01,
#           0.1837, -0.3347,  0.6709, -0.6916,  0.2060,  0.5294,  1.1485,  0.1598,
#          -0.9941, -0.1216,  1.2143, -0.1763, -0.4682, -0.5101, -0.7690, -1.0940,
#          -0.7742]])
#   Logits Bass:
# tensor([[-0.1486, -0.2308, -0.2959,  0.3261,  0.1622,  0.0207, -0.4037, -0.1054,
#           0.2236, -0.3152,  0.1591,  0.6711, -0.5644,  0.5711,  0.6231,  0.7416,
#          -0.2994,  0.8035,  0.1884,  0.2595,  0.8771,  0.0508,  0.4218, -0.5394,
#          -0.0960, -0.5004,  0.0693, -0.4824,  0.1085, -0.1816,  0.3897,  0.2029,
#          -1.0535, -1.0734, -0.1587, -0.0377,  0.3537,  0.0777, -0.4892,  0.1345,
#           0.8990,  0.1909,  0.2135, -0.0633,  0.9358, -0.3527,  0.3596,  0.2479,
#          -0.5039,  0.9294,  0.4389,  0.1802,  0.2344, -0.0235, -0.7730, -0.6303,
#          -0.0622, -0.2698, -0.0963, -1.0495,  1.0480, -0.6936,  0.4070, -0.0642,
#          -0.0620,  0.0745,  0.6824, -0.8809,  0.0164,  0.3671,  0.9599,  1.4451,
#           1.0565, -0.3824, -0.4532, -0.1320,  1.4345, -0.3383, -0.5673,  1.3692,
#           0.5461, -0.1508,  0.2819,  0.5662,  0.1094, -0.5324,  0.7914, -0.1227,
#          -0.3281,  0.5978, -1.0959,  0.5659, -0.2067,  0.0030,  0.2601,  0.3786,
#          -0.3780,  0.3428,  0.3952, -0.1685, -0.6049, -0.2688,  0.1260, -1.2246,
#          -0.3891, -0.0481,  1.2655,  0.4017,  0.1609, -0.6478, -1.0717,  0.5145,
#          -0.8914,  0.2939, -0.2896, -0.4093, -0.9129,  0.6428, -0.5075,  0.2436,
#          -0.1309,  0.9636, -0.8156, -1.3713, -0.1711,  0.4194, -1.3930,  0.5790,
#          -0.2587]])
#   是否使用教师 forcing: False
#   使用模型预测:
# tensor([[[ 92, 122,  71]]])
#   更新后的 ys:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71]]])
#
# 时间步 4:
#   Logits Alto:
# tensor([[-0.7563,  0.7117,  1.3997,  0.8441,  1.7486,  1.3179,  0.4414, -1.2128,
#           0.5947,  0.0564,  1.0858, -0.5101, -0.1612, -0.6152,  0.1270, -0.4046,
#           0.2000, -0.2243,  0.0330,  0.3447, -0.0884, -0.0351,  0.3471, -1.7579,
#           1.1956, -0.0590, -0.2724,  0.1192, -0.7511,  0.0509, -0.3753, -0.6790,
#          -0.5449, -0.8833, -0.3811, -0.4169, -0.4173,  0.9960, -0.8403,  0.1176,
#          -0.5487,  0.0134, -0.1164, -0.8331, -0.3713, -0.1148, -0.4998,  0.3766,
#           0.1034, -0.0368,  0.1000, -0.2181, -0.7903, -0.6292,  0.6856,  0.0694,
#          -0.5169, -0.6006,  0.1274,  0.5307, -0.3323,  0.8605, -1.3879, -0.3061,
#          -0.0253, -0.0223,  0.1845, -1.1807, -0.7629, -0.9189,  0.2332, -0.1083,
#           3.9624e-01,  4.2679e-01,  9.1140e-01, -9.7679e-01, -3.3852e-01,
#          -9.9154e-01, -4.7762e-01, -2.8708e-02, -1.0514e+00]])
#   Logits Bass:
# tensor([[-0.5398,  0.1347, -0.1336,  0.7599,  0.5648, -0.0687, -0.4481,  0.6288,
#           0.0035,  0.2693,  0.3190,  0.7050, -0.2145,  0.1875,  0.9876,  0.7456,
#          -0.3767,  0.9856,  0.5572, -0.0091,  0.2965, -0.7022, -0.2790, -0.5141,
#          -0.0098, -0.0638, -0.2707,  0.1054,  0.1197,  0.0370,  0.8457,  0.0466,
#          -1.0705, -0.8109, -0.4442, -0.4097,  0.2424,  0.0930,  0.0609, -0.1175,
#           0.4282,  0.3516,  0.1657, -0.1114,  0.6115, -0.5641,  0.8406,  0.7847,
#          -0.2196,  0.8937,  0.4993,  0.5843,  0.3109,  0.2226, -0.2529, -0.5125,
#           0.1269, -0.3064, -0.1817, -0.8631,  0.2672, -1.2307, -0.1835, -0.4486,
#           0.4179, -0.1265,  1.2483, -1.1041,  0.2353,  0.0369,  0.7826,  1.4548,
#           0.5252, -0.0355, -0.3003, -0.1143,  1.1235, -1.1798, -0.9208,  1.2831,
#           0.5402, -0.4148, -0.0493,  0.1161,  0.3577, -0.7696,  0.3976, -0.1622,
#          -0.1556, -0.3499, -0.1652,  0.3534, -0.5667, -0.5362,  0.4063,  0.4782,
#          -0.0979, -0.1244,  0.5485, -0.3277, -0.8747, -0.0670,  0.1365, -0.3573,
#          -0.3103, -0.3031,  1.0196,  0.0813,  0.3520, -0.5537, -0.6627,  0.6760,
#          -0.8808,  0.3200, -0.9500, -0.0333, -1.0416,  0.6028, -0.9850,  0.1599,
#          -0.4904,  0.9083, -0.9849, -1.7812,  0.1405,  0.3765, -1.0228,  0.5013,
#          -0.2617]])
#   是否使用教师 forcing: True
#   使用目标输入 (Ground Truth):
# tensor([[[ 38,  44, 118]]])
#   更新后的 ys:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71],
#          [  4, 118,  79],
#          [ 38,  44, 118]]])
#
# 时间步 6:
#   Logits Alto:
# tensor([[-0.0917,  0.9570,  0.7307,  0.8958,  1.6768,  1.6824,  0.2983, -1.1071,
#           0.2982, -0.2555,  1.5376, -0.3607,  0.0219, -0.4536, -0.1766, -0.3749,
#           0.2213, -0.2716,  0.4048,  0.3092,  0.0291,  0.0599,  0.3973, -1.4975,
#           0.3821, -0.0694,  0.0109,  0.3272, -1.0568,  0.0876, -0.6768, -0.0380,
#          -0.5908, -0.6189, -0.7065,  0.1522, -0.0234,  0.5437, -0.7272, -0.1114,
#          -0.4219, -0.0288, -0.4213, -0.5427, -0.9351, -0.6009,  0.3255, -0.0774,
#          -0.1337, -0.7483,  0.2196,  0.1492, -0.3938, -0.4201,  0.6449,  0.1052,
#           0.0166, -1.0208,  0.0074,  0.5555, -0.0576,  0.6728, -0.7505, -0.1573,
#          -0.3682, -0.1904,  0.4916, -0.3099, -0.6474, -1.0105,  0.0250,  0.5500,
#          -0.1491,  0.7793,  0.8139, -0.0732, -0.4874,  0.1045,  0.7135, -0.6802,
#           0.2726, -0.6581, -0.5433, -0.9309,  0.4616, -0.5097, -0.4677, -0.1934,
#           0.1532,  0.1055,  0.6623, -1.0908,  0.1878, -0.1378,  0.3260,  1.0350,
#           0.6657,  0.2808,  0.2966, -0.4150,  1.0056, -0.3241, -0.5074,  0.9916,
#           0.8297, -0.0976,  0.3444,  0.1604,  0.4762, -0.2753,  0.6265, -0.6399,
#          -0.3251, -0.2899, -0.0372, -0.0360, -0.1580,  0.0434,  0.3627,  0.0456,
#          -0.1208,  0.4108,  0.5170, -0.4006, -0.3359, -0.3940,  0.1699, -0.8480,
#           0.0622, -0.0158,  0.6806,  0.3569,  0.1992, -0.6056, -1.4231,  0.6514,
#          -0.8527,  0.1563, -0.2414,  0.3186, -0.9921,  0.0774, -1.0028,  0.1009,
#          -0.6108,  0.7909, -1.1847, -1.5603,  0.2674, -0.2309, -1.2222,  0.5654,
#          -0.6538]])
#   是否使用教师 forcing: True
#   使用目标输入 (Ground Truth):
# tensor([[[101, 105,  57]]])
#   更新后的 ys:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71],
#          [  4, 118,  79],
#          [ 38,  44, 118],
#          [101, 105,  57]]])
#
# 时间步 7:
#   Logits Alto:
# tensor([[-0.3884,  1.3114,  0.2225,  0.6331,  1.6764,  1.6901,  0.2600, -1.0350,
#           0.0755, -0.2102,  1.3024, -0.4202, -0.1778, -0.3368, -0.0766, -0.1173,
#          -0.1639, -0.1796,  0.1348,  0.2731, -0.0290,  0.2963,  0.5473, -1.8492,
#           0.8739, -0.1494,  0.0483,  0.2646, -0.6977,  0.0537, -0.3896,  0.3322,
#          -0.5604, -0.3914, -0.9445, -0.4330,  0.2813,  0.2683, -0.6637,  0.0333,
#          -0.4485,  0.6002, -0.7332, -0.5738, -0.7930, -0.1695,  0.3743,  0.3619,
#          -0.0478, -0.3789, -0.0046, -0.1031, -0.8825, -0.5552,  0.2172,  0.4538,
#          -0.7012, -0.4638,  0.3792,  0.7074,  0.5126,  0.8896, -0.8686, -0.4336,
#          -0.2377,  0.0804,  0.7923, -0.7510, -0.7593, -0.7800,  0.0733,  0.4761,
#           0.1372, -0.6656,  0.5168, -0.0548, -0.4761,  0.0202,  0.3188, -0.0530,
#          -0.6765, -0.1795, -0.7309, -0.5496,  0.1918,  0.4977, -0.5387, -0.4816,
#          -1.3434,  0.2934, -0.7252, -0.2500,  1.2237, -0.5988, -0.6701,  0.8748,
#           0.7587, -0.5359, -0.4327, -0.0367,  0.3153, -0.7015,  0.6699,  1.4838,
#          -0.2827,  0.3598,  0.2193,  0.0118,  0.4028,  0.0660, -0.8340,  0.3192,
#           0.8786,  0.4339, -0.5295,  0.4358,  1.1821,  0.8975,  0.1323, -0.0503,
#           0.3035,  0.0736,  0.2476,  0.7986,  0.1116, -0.5426, -0.3078, -0.5975,
#          -0.6900]])
#   Logits Tenor:
#          -0.4811,  0.3668, -0.6885, -0.0097, -1.5379,  0.1793, -1.0826, -0.0354,
#          -0.2773,  1.2783, -0.6884, -1.2396,  0.5422, -0.0334, -1.0626,  0.6577,
#          -0.1377]])
#   是否使用教师 forcing: False
#   使用模型预测:
# tensor([[[  5,  50, 121]]])
#   更新后的 ys:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71],
#          [  4, 118,  79],
#          [ 38,  44, 118],
#          [101, 105,  57],
#          [  5,  50, 121]]])
#
# 时间步 8:
#   Logits Alto:
# tensor([[-0.0717,  1.1593,  1.1272,  0.6703,  0.7977,  0.7907, -0.3370, -0.7390,
#          -0.1569,  0.6048,  0.6387, -0.7841,  0.1765, -0.6980,  0.0957, -0.1622,
#           0.3829, -0.1563,  0.1928,  0.2578,  0.0387, -0.3170,  1.1014, -1.4633,
#           1.1957, -0.9174,  0.3237,  0.4153, -0.5177,  0.1048, -0.5566, -0.1548,
#          -0.4770, -0.0906, -0.3546,  0.3432, -0.1658,  0.9847, -1.0536,  0.0674,
#           0.1395,  0.1345, -0.1650, -0.8367, -0.9171,  0.0094, -0.1071,  0.1174,
#           0.3878, -0.7185,  0.6542, -0.8365, -0.6943, -0.0072,  0.3846,  0.2590,
#          -1.0533, -0.1932,  0.2927,  1.0600, -0.0032,  0.4386, -0.3585, -0.6010,
#          -0.2500,  0.7064,  0.2882, -0.5375, -0.8961, -0.6538, -0.4656,  0.9422,
#           0.1052, -1.2136,  0.3168,  0.2253,  0.2147, -0.7138, -0.6765,  0.1320,
#          -0.1366, -0.0089, -0.2560, -1.1766,  0.4604,  0.2081, -0.6130, -0.1730,
#          -0.9146,  0.5108, -1.0236,  0.1814,  0.9307, -0.5954, -0.8710,  0.6349,
#           0.7797, -0.9224, -0.6390, -0.0783, -0.2876, -1.3717,  0.4027,  1.4421,
#           0.0961, -0.4265,  0.3669,  0.1693,  0.3002, -0.0305, -0.7160,  0.1785,
#           0.1984,  0.4143,  0.1789,  0.8783,  1.3389,  0.8901,  0.1964,  0.4366,
#           0.4981,  0.3155,  0.4665,  0.1671,  0.2374, -0.5432, -0.3666, -0.2091,
#          -0.2532]])
#   Logits Tenor:
# tensor([[-1.0618, -0.1935,  0.5381,  1.1027, -1.1681, -0.2302,  0.7324, -0.3263,
#           0.6629, -0.9568,  0.4134, -0.4625, -0.3443, -0.6332, -0.1334, -0.2136,
#          -0.2549, -0.1747,  0.9345,  0.5304, -0.2424,  0.3550,  1.2437,  0.2707,
#           0.5835, -0.5971,  0.1962, -0.2717,  0.1552, -0.4302,  0.6716,  0.5156,
#           0.1657,  0.8160, -0.4596, -0.3906,  0.2129, -0.7760, -0.4562, -0.2081,
#           0.0154, -0.1481,  0.8130, -1.1163, -0.0675, -1.2695,  0.5988, -0.5451,
#           0.2644,  0.3949,  1.3794,  0.2429,  0.4571, -0.0812,  0.2125,  0.3764,
#           0.2654,  0.1180, -0.7293,  0.5422, -0.3562,  0.0173, -0.9686, -0.2350,
#           0.2571, -1.4113,  0.8661, -0.1583,  0.8918, -1.3782, -0.1607, -0.4365,
#           0.1668,  0.0174,  0.4575, -0.5833,  0.4881,  0.3931,  0.0551, -0.3308,
#           0.1085,  0.3457,  0.5677,  1.0118, -0.0933, -0.0882,  0.2241, -0.2146,
#           0.0091,  0.3606,  0.0599,  0.5588,  0.5609, -0.1870,  0.1652,  0.1186,
#           0.8537,  0.2171,  0.4554,  1.3815, -0.3924,  0.2769, -0.0711, -0.6045,
#           1.2210, -0.7244,  0.0276, -1.6308,  0.2539,  0.5785, -0.0570,  0.2322,
#           0.6009, -0.3071,  0.3753, -0.7306, -0.2607,  0.4769,  1.2093,  0.0568,
#          -0.9412,  0.1813,  0.9101, -0.3646,  0.0764, -1.7337, -0.6135, -1.3511,
#          -1.1100]])
#   Logits Bass:
# tensor([[-0.8037, -0.1181, -0.0406, -0.0424,  0.0262,  0.2108, -0.4782, -0.0194,
#          -0.1747,  0.1271, -0.2216,  0.1967,  0.0701,  0.2695,  1.1881, -0.0221,
#          -0.0538,  0.7628,  0.3389, -0.0811,  0.7693, -0.3431, -0.5327, -0.3977,
#          -0.3467,  0.1149,  0.4343,  0.0697,  0.1208, -0.2805,  1.0077,  0.6366,
#          -0.5274, -0.3017,  0.2750, -0.2183, -0.0850,  0.2424,  0.0162, -0.5097,
#           0.2228,  0.0463,  0.1628,  0.3571,  0.9817, -1.0865,  1.1804,  0.1188,
#          -0.5341,  0.3792,  0.4381, -0.1803,  0.1082, -0.4993,  0.3617, -0.7195,
#           0.4475, -0.5061, -0.0688, -0.4722,  0.2528, -0.0108, -0.0106, -0.0675,
#           0.7717,  0.6986,  0.4011, -0.6000,  0.2892,  0.1219,  0.4430,  0.8045,
#           0.2226,  0.1447, -0.0499, -0.1090,  0.8732, -0.3267, -0.1395,  0.1425,
#           0.5767,  0.2725,  0.9009,  0.3323,  0.1849, -0.3299,  1.0110, -0.0791,
#          -0.4739,  0.0417, -0.2099,  0.8396,  0.3482,  0.4519,  0.4753,  0.2806,
#           0.0236,  0.1921,  0.0722, -0.3007,  0.0365, -0.7698, -0.3795, -0.7952,
#          -0.3202,  0.1701,  1.2192,  0.0496,  0.0092, -0.6053, -1.0731,  0.1228,
#          -0.4234,  0.5286, -0.2942,  0.7245, -1.1442, -0.3038,  0.0363,  0.4887,
#           0.0155,  0.6442, -0.7107, -1.6555,  0.2927,  0.0977, -1.3205,  0.5372,
#          -0.4621]])
#   是否使用教师 forcing: True
#   使用目标输入 (Ground Truth):
# tensor([[[112,  82,  18]]])
#   更新后的 ys:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71],
#          [  4, 118,  79],
#          [ 38,  44, 118],
#          [101, 105,  57],
#          [  5,  50, 121],
#          [112,  82,  18]]])
#
# 时间步 9:
#   Logits Alto:
# tensor([[ 0.2932,  1.7579,  0.5505,  0.6925,  1.4263,  0.8454,  0.4927, -1.1385,
#           0.3277,  0.2608,  0.9841, -1.1209, -0.3265, -0.3032,  0.0665, -0.2450,
#          -1.1672e-01,  6.9840e-01, -8.2685e-02, -3.3490e-01,  4.2635e-01,
#           4.4936e-01,  1.0379e+00,  1.2577e-01, -6.0158e-01,  2.6872e-01,
#           5.1144e-01,  6.2290e-01, -2.1044e-01,  2.5138e-01,  1.1245e+00,
#          -5.0669e-01,  6.3533e-01,  3.1754e-04, -4.8640e-01,  1.0582e+00,
#          -4.8281e-01, -1.4592e-01, -1.0862e+00,  3.0250e-01,  6.6856e-01,
#          -1.2895e-01, -1.5304e-01,  3.5351e-01, -7.3403e-01,  3.6425e-01,
#          -1.1042e+00, -3.0051e-01,  2.5535e-01,  1.2030e+00,  5.5378e-02,
#          -2.9779e-01,  1.0183e-01,  8.0663e-01, -6.9235e-01,  2.5951e-01,
#          -1.1244e+00, -5.3663e-01, -8.7558e-01, -1.4083e+00]])
#   Logits Bass:
# tensor([[-0.3308, -0.1930, -0.1242, -0.0379,  0.4789,  0.1756, -0.0628, -0.6607,
#          -0.5499,  0.8124, -0.4413,  0.1579, -0.1520,  0.2265,  1.7653, -0.1148,
#          -0.0885,  1.2648, -0.1185, -0.0527,  0.5316, -0.6055, -0.3242, -0.4545,
#          -0.0565, -0.4851,  0.2958,  0.1120, -0.5951,  0.1565,  1.1679,  0.5239,
#          -0.9905, -0.3803, -0.1777, -0.5524, -0.1909, -0.2989,  0.0816, -0.1397,
#           0.6302,  0.4677, -0.0609,  0.2901,  1.4555, -0.8876,  1.1642,  0.5303,
#          -0.2899,  0.3263,  0.9371,  0.4595, -0.5544, -0.0363,  0.1340, -0.3242,
#           0.9149, -1.0220, -0.1359, -1.2951,  0.6955, -0.2590,  0.1291, -0.5152,
#           0.6435,  0.1594,  0.3395, -0.3287,  0.1487, -0.0598,  0.6045,  1.2412,
#          -0.1916,  0.0632,  0.4314, -0.0192,  1.0570, -0.0510, -0.3324,  0.1786,
#           0.2439,  0.4825,  0.9896,  0.4679, -0.2075, -0.3161,  0.7859, -0.7265,
#          -0.4464,  0.1310, -0.4581, -0.0419,  0.4550,  0.1005,  0.0172,  0.1778,
#          -0.4246,  0.4274,  0.1333,  0.1269, -0.1886, -0.7019, -0.0342, -0.8024,
#           0.2282,  0.1384,  0.9796,  0.0800,  0.2231, -0.7405, -0.9754,  0.4493,
#          -0.1244,  0.4123, -0.4049,  0.4609, -0.9140,  0.2381, -0.3269, -0.1503,
#          -0.7454,  0.5775, -0.9447, -1.4112, -0.0443, -0.2315, -0.8477,  0.6054,
#          -0.5571]])
#   是否使用教师 forcing: False
#   使用模型预测:
# tensor([[[92, 50, 14]]])
#   更新后的 ys:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71],
#          [  4, 118,  79],
#          [ 38,  44, 118],
#          [101, 105,  57],
#          [  5,  50, 121],
#          [112,  82,  18],
#          [ 92,  50,  14]]])
#
# 时间步 10:
#   Logits Alto:
# tensor([[-0.2162,  1.6545,  1.1912,  1.0202,  1.3005,  0.6927,  0.3089, -1.1199,
#          -0.4472,  0.1097,  0.4281, -1.1028,  0.3689, -1.8140, -0.2753, -1.0521,
#          -1.3602]])
#   Logits Bass:
# tensor([[-0.4164, -0.5473,  0.0052,  0.1596, -0.0373, -0.0213, -0.2913, -0.1937,
#          -0.2465,  0.3691, -0.2994,  0.2943, -0.4677,  0.7701,  1.3008, -0.0106,
#          -0.2516,  1.1178,  0.4554,  0.0694,  0.6056, -0.3295, -0.2626, -0.6323,
#          -0.1479, -0.0395,  0.0037,  0.6181, -0.3559, -0.4626,  1.4485,  0.3562,
#          -0.5815, -0.4007, -0.2933, -0.2022,  0.4571,  0.0409, -0.1267, -0.4930,
#           0.1614,  0.5421, -0.1709,  0.0020,  0.8108, -0.9046,  0.9666,  0.5120,
#           0.0756,  0.2081,  0.2884, -0.0079, -0.0595, -0.2490,  0.3673, -0.9490,
#           0.6471, -0.9960, -0.2471, -0.6722,  0.6732, -0.4369,  0.2744, -0.0730,
#           0.7247,  0.2159,  0.8953, -0.4296,  0.1649, -0.4137,  0.6899,  1.4801,
#          -0.0095, -0.3192,  0.1842, -0.2075,  1.2804, -0.1137, -0.1698,  0.3486,
#           0.1929, -0.0588,  1.1683,  0.5047,  0.8586, -0.0084,  0.5638, -0.3472,
#          -0.8252, -0.0786, -0.2251, -0.0869,  0.0603,  0.0751,  0.0737, -0.4232,
#          -0.0412, -0.0968,  0.3060,  0.2732, -0.0233, -0.6013,  0.1787, -1.1150,
#          -0.0872,  0.1528,  1.4675,  0.2340, -0.0901, -0.5178, -1.2953,  0.3492,
#          -0.1480,  0.7154, -0.2297,  0.6629, -0.8510,  0.2065, -0.1795, -0.2229,
#          -0.5858,  1.2865, -0.6753, -1.3193,  0.6287,  0.1765, -1.3038,  0.6136,
#          -0.8874]])
#   是否使用教师 forcing: True
#   使用目标输入 (Ground Truth):
# tensor([[[26, 82, 24]]])
#   更新后的 ys:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71],
#          [  4, 118,  79],
#          [ 38,  44, 118],
#          [101, 105,  57],
#          [  5,  50, 121],
#          [112,  82,  18],
#          [ 92,  50,  14],
#          [ 26,  82,  24]]])
#
# 最终生成的序列:
# tensor([[[128, 128, 128],
#          [ 24,  37,  47],
#          [ 10, 122, 106],
#          [ 92, 122,  71],
#          [  4, 118,  79],
#          [ 38,  44, 118],
#          [101, 105,  57],
#          [  5,  50, 121],
#          [112,  82,  18],
#          [ 92,  50,  14],
#          [ 26,  82,  24]]])
# /opt/anaconda3/envs/sb/lib/python3.10/site-packages/torch/nn/modules/transformer.py:385: UserWarning: enable_nested_tensor is True, but self.use_nested_tensor is False because encoder_layer.self_attn.batch_first was not True(use batch_first for better inference performance)
#   warnings.warn(

# %%
#!/usr/bin/env python
import torch
import random
from methon1 import build_model, DEVICE, SOS_TOKEN

def debug_generation(model, src, trg, teacher_forcing_ratio=0.5):
    """
    调试 scheduled sampling 分支下的生成过程：
      - 对于每个时间步，打印当前 decoder 的输出 logits，
      - 打印是否采用了教师 forcing，
      - 打印更新后的 decoder 输入序列 ys。
    """
    model.eval()
    src = src.to(DEVICE)
    trg = trg.to(DEVICE)
    # 编码 source 序列
    src_emb = model.src_embedding(src).transpose(0, 1)  # [src_len, batch, d_model]
    memory = model.transformer.encoder(src_emb)
    batch_size, trg_len, _ = trg.shape

    # 初始化 decoder 输入：使用 SOS 三元组
    ys = torch.full((batch_size, 1, 3), SOS_TOKEN, dtype=torch.long, device=src.device)
    print("Initial ys (SOS):")
    print(ys)

    for t in range(trg_len):
        # 获取当前 decoder 输入序列的嵌入表示，并构造 mask
        tgt_emb = model.tgt_embedding(ys).transpose(0, 1)  # [current_len, batch, d_model]
        current_len = tgt_emb.size(0)
        tgt_mask = model.generate_square_subsequent_mask(current_len).to(src.device)
        out = model.transformer.decoder(tgt_emb, memory, tgt_mask=tgt_mask)
        out = out.transpose(0, 1)  # [batch, current_len, d_model]
        last_out = out[:, -1, :]   # [batch, d_model]

        # 计算三个声部的 logits
        curr_alto = model.fc_alto(last_out)    # [batch, vocab_size]
        curr_tenor = model.fc_tenor(last_out)
        curr_bass = model.fc_bass(last_out)

        print(f"\nTime step {t+1}:")
        print("  Alto logits:\n", curr_alto)
        print("  Tenor logits:\n", curr_tenor)
        print("  Bass logits:\n", curr_bass)

        # 决定是否采用教师 forcing
        use_teacher = (torch.rand(1).item() < teacher_forcing_ratio)
        print("  Use teacher forcing:", use_teacher)
        if use_teacher:
            # 使用目标值作为下一步输入
            next_input = trg[:, t:t+1, :]
            print("  Using ground truth triple:\n", next_input)
        else:
            # 使用模型预测（对每个声部取 argmax）作为下一步输入
            pred_alto = curr_alto.argmax(dim=1, keepdim=True)  # [batch,1]
            pred_tenor = curr_tenor.argmax(dim=1, keepdim=True)
            pred_bass = curr_bass.argmax(dim=1, keepdim=True)
            next_input = torch.cat([pred_alto, pred_tenor, pred_bass], dim=1).unsqueeze(1)  # [batch,1,3]
            print("  Using predicted triple:\n", next_input)
        # 更新 decoder 输入序列
        ys = torch.cat([ys, next_input], dim=1)
        print("  Updated ys:\n", ys)
    return ys

if __name__ == "__main__":
    # 加载模型及构造必要配置。
    model, optimizer, criterion = build_model()

    # 构造一个简单的样例输入（这里批量大小为 1，序列长度设为 10）。
    # 注意：音符的取值范围一般为 1~127, PAD_TOKEN 设为0；SOS_TOKEN 已定义为128。
    src_sample = torch.tensor([[random.randint(1, 127) for _ in range(10)]], dtype=torch.long)
    trg_sample = torch.tensor([[[random.randint(1, 127) for _ in range(3)] for _ in range(10)]], dtype=torch.long)

    print("Soprano sample:")
    print(src_sample)
    print("Target ATB sample:")
    print(trg_sample)

    # 运行调试函数，打印生成过程中各步信息。
    generated_seq = debug_generation(model, src_sample, trg_sample, teacher_forcing_ratio=0.5)
    print("\nFinal generated sequence:")
    print(generated_seq)
# Out:
# Soprano sample:
# tensor([[ 11,  43,  94,   8,  15,  86, 120,  54,  31, 118]])
# Target ATB sample:
# tensor([[[ 87,  41,  35],
#          [108, 108,  31],
#          [ 18,  73,  42],
#          [  6,   1,  93],
#          [107,  57,  73],
#          [ 29,  44,  91],
#          [  3,  93, 121],
#          [ 56, 126,  50],
#          [ 34,  48,  30],
#          -0.3364,  0.4869,  0.2907, -0.4026,  0.6484,  0.6729,  0.5316, -0.2246,
#          -0.0993,  0.8409, -0.3021,  1.1210,  0.5132,  0.3676, -0.8449, -0.2034,
#          -0.0915, -1.4964,  1.1944,  0.1748,  0.7042,  0.2914, -0.3902,  0.1182,
#           0.0293, -0.2201, -0.0557,  0.3891,  0.2335,  0.3281,  0.5448,  0.5749,
#          -0.0585, -0.5365,  0.7466,  0.0327,  0.3680,  0.2136,  0.4770,  1.3428,
#          -0.5103,  0.4952,  0.6362,  0.8467,  0.7598,  0.8253,  0.1676,  0.0522,
#           0.5603,  0.3558,  0.3643,  0.4826, -0.4440, -0.0688, -0.7988,  0.1653,
#           0.7825, -0.2908,  0.6758, -0.2743,  0.6929, -0.2957,  0.1178,  0.3136,
#          -0.3737, -0.6739, -0.5800,  0.6103,  0.5526,  0.2910,  0.0937, -0.7201,
#          -0.2718,  0.4622,  0.0401,  0.0904,  0.4755, -0.8319, -0.1775,  0.9253,
#           0.6169, -0.6838, -0.5207, -0.5879, -0.8215,  0.7063,  0.2320,  0.2140,
#           0.2561, -0.2807, -1.2712, -0.1006, -0.5384,  0.0434,  0.1970,  0.0352,
#          -0.4251]], grad_fn=<AddmmBackward0>)
#   Bass logits:
#  tensor([[-0.6955,  0.1903, -1.0176, -0.3079, -0.2619, -0.8696, -0.4914, -0.7643,
#          -0.3423,  0.0121,  0.8457,  0.2375, -0.3054, -0.6093, -0.6543, -0.4407,
#           0.2559, -0.4682,  1.2235,  1.0517, -0.1940, -0.9729,  0.6587, -0.1455,
#           0.0319, -0.5147, -0.5041, -0.2329, -0.1400, -0.4292, -0.6171, -0.0882,
#           0.9126,  0.1910, -0.2310,  0.1136,  0.2049,  0.7386,  0.4089, -0.5373,
#          -0.9444, -0.6831, -0.6928,  0.7482, -0.0931, -0.0686, -0.5743,  0.3210,
#          -0.7561, -0.7989,  0.7570, -0.0813, -0.0496, -0.1050,  0.0310, -0.6804,
#          -0.2337, -1.0099, -0.2862,  0.3919, -1.1388,  0.0191,  1.3130, -0.5413,
#           0.2915,  0.0611,  0.5910, -1.1858, -0.6570,  0.3073,  0.0441, -0.0903,
#           0.1943, -0.4643, -0.4519, -0.3059,  0.4953,  1.0538,  0.6427, -0.5600,
#           0.0919,  0.3241, -0.1502,  0.2730,  0.4732, -0.7798,  0.0614, -0.9836,
#           0.4659,  0.1651, -0.4433, -0.2592,  0.6932, -0.0781,  0.8025, -1.3757,
#          -0.4112,  0.0413,  0.6553, -0.9467, -0.2672,  0.6101, -0.3034,  0.2057,
#          -0.1001, -0.2723,  0.8764,  0.6625,  1.4273, -0.1994, -0.2708, -0.8935,
#           1.0988, -0.2432, -1.4327,  0.0017,  0.2745, -0.0689,  0.8586, -0.5526,
#           0.6237, -0.5186,  0.5232,  0.3822,  0.3014, -0.4238,  0.3071,  0.4323,
#           0.3323]], grad_fn=<AddmmBackward0>)
#   Use teacher forcing: True
#   Using ground truth triple:
#  tensor([[[18, 73, 42]]])
#   Updated ys:
#          -2.8281e-01, -2.1466e-01, -6.8120e-01, -2.3583e-01,  7.6008e-01,
#          -1.4872e+00, -2.6241e-01,  1.7606e-01, -4.6659e-01, -1.0707e+00,
#          -8.3161e-01,  8.2830e-02, -5.5862e-01,  5.3450e-01,  2.3916e-01,
#          -1.1336e+00,  6.0222e-01,  7.8317e-01,  1.3160e+00, -3.9947e-01,
#           4.8852e-01, -4.4156e-01,  4.6273e-01, -4.9538e-01, -1.1891e+00,
#           9.7913e-04,  1.1339e+00,  2.5570e-01,  5.8147e-01, -7.0402e-01,
#           7.6012e-01, -1.0924e+00,  3.9626e-01, -4.4035e-01, -2.7640e-01,
#          -2.4054e-01,  9.1091e-02, -3.6228e-01,  5.0441e-02]],
#        grad_fn=<AddmmBackward0>)
#   Use teacher forcing: False
#   Using predicted triple:
#  tensor([[[ 83,  12, 108]]])
#   Updated ys:
#  tensor([[[128, 128, 128],
#          [ 87,  41,  35],
#          [108, 108,  31],
#          [ 18,  73,  42],
#          [ 12,  12,  19],
#          [ 83,  12, 108]]])
#
# Time step 6:
#   Alto logits:
#  tensor([[-0.0694,  0.5534, -0.5522, -0.0131,  0.3287, -0.2394, -1.0488,  0.6287,
#           0.1191,  0.4370, -1.5801,  1.0139,  0.4210, -1.0367,  0.1260,  0.1831,
#          -0.6631, -0.2211, -0.7017, -0.3523, -0.6398, -0.1069, -0.1264,  0.5920,
#           0.3329, -0.1138, -0.4524,  0.8268, -0.4192, -0.6283, -0.2129, -0.6362,
#          -0.0315,  0.4611,  0.0808, -0.2748, -0.7395,  0.3808, -0.3343, -0.6085,
#          -0.2648,  0.8437, -0.6684, -0.4359,  0.6796,  0.0857,  0.5046, -0.7604,
#          -0.1650, -0.6686, -1.1062, -0.7225, -0.2563,  0.8832, -0.6466,  0.9241,
#           0.6069,  0.8856,  1.0479,  0.2744,  0.0587, -0.2142, -0.4732,  0.5644,
#          -0.0985,  0.8307,  1.1361, -0.2634,  0.1192, -0.2827, -1.3066, -1.4548,
#          -0.5796,  0.1905,  0.5181, -0.5165,  0.8606, -0.1557,  0.2154,  0.4244,
#           0.5736, -0.4511, -1.0790,  1.8347,  0.2280, -0.5638, -0.2150,  0.2039,
#           0.4026, -0.3862,  0.3234, -0.1149, -0.5571,  0.8194, -0.2173,  0.3239,
#           0.0217,  0.3025,  0.0661, -0.7696,  0.8415,  0.3596,  0.4548, -0.4428,
#          -0.3880, -0.6652,  1.2200,  0.4068, -0.1131,  0.6713, -0.3378,  0.4584,
#           0.4816,  0.5351, -0.6295, -0.8585, -0.0504,  0.3890, -0.7202, -0.0787,
#           0.7330, -0.0227,  0.3565, -0.7216,  0.1462, -0.5185, -0.3509,  0.7910,
#          -1.0255]], grad_fn=<AddmmBackward0>)
#   Tenor logits:
#  tensor([[-0.3813, -0.4229, -0.0928,  0.5901, -0.2389, -1.4277,  0.2923, -0.3113,
#           0.2118,  0.4742,  0.6024, -0.8967,  1.3367,  0.2993,  0.7976, -0.4532,
#           0.3001]], grad_fn=<AddmmBackward0>)
#   Use teacher forcing: True
#   Using ground truth triple:
#  tensor([[[29, 44, 91]]])
#   Updated ys:
#  tensor([[[128, 128, 128],
#          [ 87,  41,  35],
#          [108, 108,  31],
#          [ 18,  73,  42],
#          [ 12,  12,  19],
#          [ 83,  12, 108],
#          [ 29,  44,  91]]])
#
# Time step 7:
#   Alto logits:
#  tensor([[-0.5900,  0.2870, -0.0367, -0.4743,  0.2909,  0.2966, -0.7220,  0.4948,
#           0.0041,  0.3634, -0.8778,  0.7721,  0.7996, -0.4384,  0.5494, -0.3578,
#          -0.1208, -0.1353,  0.3818,  0.3749,  0.1896,  0.4527, -0.3442,  0.7171,
#           0.1537,  0.3762, -0.8729,  0.8479,  0.6839, -0.7321,  0.2348, -0.2451,
#          -0.8548,  0.4744,  0.5040, -0.2796, -0.1709, -0.1024, -0.3129, -0.6698,
#           1.0080,  0.8552, -0.1601, -0.7281,  0.2501,  1.0188,  0.9019,  0.0087,
#          -0.2728, -0.3824, -0.5251, -0.2107, -0.5319,  0.9554, -0.2378,  0.8358,
#           0.0717, -0.2772,  0.9621, -0.3048,  0.1246, -0.0733, -0.4085, -0.2549,
#          -0.3693,  0.0782,  0.5864, -0.8051,  0.2377, -0.4514, -1.0686, -0.9127,
#          -0.6746, -0.0307, -0.2099, -0.3779,  0.7667,  0.7279,  0.1552,  0.0913,
#          -0.3384, -0.3168, -0.4521,  0.7547,  0.4111, -0.3231,  0.1284, -0.1089,
#           0.4894,  0.7408, -0.0620, -0.1200, -0.3866,  0.5111,  0.3820,  1.1940,
#          -0.3805, -0.1226, -0.0685, -0.3176,  1.2479,  0.5139,  0.6421, -0.1778,
#          -1.0537, -0.4995,  1.5351,  0.9395,  0.3811,  0.2295, -0.3391,  0.6076,
#           0.4967,  0.5532, -0.9799, -1.4513, -0.0041,  0.3241, -0.1435, -0.3974,
#           0.3696,  0.0788,  0.3006, -0.5629,  0.3183, -0.8579, -0.0036,  0.9676,
#          -0.1235]], grad_fn=<AddmmBackward0>)
#   Tenor logits:
#  tensor([[ 4.5443e-01, -1.8110e-01,  1.7922e-01,  4.1764e-01,  6.6903e-01,
#          -1.3706e+00,  4.0843e-02, -5.1840e-01,  6.9743e-03,  2.5132e-01,
#           3.3113e-01, -5.7638e-01,  6.6632e-01,  7.1233e-01, -1.6420e-01,
#          -3.0793e-01,  4.2343e-01,  3.1681e-01, -5.3773e-01, -1.0876e+00,
#           7.7376e-02,  5.4496e-01,  5.1098e-01, -1.0059e+00,  7.7062e-02,
#          -2.6724e-02,  3.6139e-01,  1.0517e+00,  1.3132e-01,  3.2080e-01,
#           6.3165e-01, -5.3187e-01,  7.5697e-02,  5.5758e-01,  2.9883e-01,
#          -2.7292e-01,  1.6291e-01,  4.9549e-01,  2.2034e-01, -3.0787e-01,
#          -1.1077e+00,  5.4920e-01, -8.0984e-01,  3.3696e-01,  5.1990e-01,
#           4.3114e-01, -4.2913e-01, -3.7159e-02,  8.6139e-01, -2.1377e+00,
#          -0.8192, -0.6879, -0.2212,  0.4948, -0.0029, -0.1527, -0.0187,  0.1758,
#          -0.0773, -0.4845,  1.0691, -0.3985,  0.1775, -0.1323, -0.0475,  0.4138,
#          -0.8442, -0.5644, -0.4268,  0.1945, -1.2310,  0.4320,  0.6095, -0.8100,
#          -0.0829, -0.2644,  0.0550, -1.3270,  0.1265,  0.4542, -0.3933, -0.4889,
#           0.1396, -0.5400, -0.6698, -0.9175,  0.5823,  0.9435,  0.7948, -0.5137,
#          -0.7453, -0.2125,  0.1390, -0.2570, -0.0412, -0.9549, -1.1111, -0.9048,
#           0.1238,  0.2420, -0.5665, -0.4537,  0.8656, -0.3412,  0.5629, -1.5368,
#          -0.2123, -0.3708,  0.1539, -0.2662, -0.8590, -0.4837, -0.2321,  0.8375,
#           0.3309, -0.4242,  0.6755,  0.5048,  0.3876,  0.0856, -0.4280, -0.7820,
#          -0.6503, -0.4525, -0.6380, -0.2634,  0.1379, -0.1032,  1.0469, -1.5680,
#           0.4202,  0.1097, -0.3348, -0.3036, -0.4172, -0.1434,  0.5166, -0.0097,
#           0.3188]], grad_fn=<AddmmBackward0>)
#   Use teacher forcing: False
#   Using predicted triple:
#  tensor([[[106, 105,  19]]])
#   Updated ys:
#  tensor([[[128, 128, 128],
#          [ 87,  41,  35],
#          [108, 108,  31],
#          [ 18,  73,  42],
#          [ 12,  12,  19],
#          [ 83,  12, 108],
#          [ 29,  44,  91],
#          [106, 117,  50],
#          [106, 105,  19]]])
#
# Time step 9:
#   Alto logits:
#  tensor([[-0.0445,  0.4725, -0.2204, -0.7168,  0.6203, -0.0268, -0.4532, -0.0613,
#          -0.1797,  0.4478, -0.5267,  0.8203,  0.9640, -0.5516,  0.2322, -0.9858,
#           0.0866, -0.0839, -0.7102,  0.4934, -0.1917,  0.3948, -0.6045,  0.8309,
#          -0.3177, -0.6081, -0.5586,  0.9618,  0.1982, -0.2786,  0.5330, -0.0136,
#          -1.0363,  0.7102, -0.4350,  0.3718,  0.2375,  0.5462, -0.5203, -0.5188,
#           0.7519,  1.0470, -0.5565, -0.7851,  1.0038,  0.2699,  1.1251, -0.4782,
#          -0.5829, -0.8902, -1.2692, -0.4468, -0.3228,  0.0889, -0.8770,  0.1191,
#           0.2471, -0.3824,  1.0293,  0.0854,  0.4156, -0.2271, -0.1590,  0.4944,
#           0.0669,  0.2564,  0.0213, -1.1586, -0.3354,  0.0709, -1.0888, -0.5428,
#          -0.5824,  0.2461,  0.2463, -0.1732,  0.5194, -0.8379, -0.5130,  0.0929,
#          -0.2878,  0.3427, -0.5891,  0.2560, -0.1699, -1.0666, -0.4796,  0.3468,
#           0.4480,  0.5032,  0.6115, -0.3149, -0.6269, -0.0186,  0.3109,  0.7407,
#           0.0837, -0.4268,  0.2047, -0.0091,  1.6610, -0.0283,  0.4326, -0.1956,
#          -0.6078,  0.0077,  1.7090,  0.2770,  0.9418,  0.8302, -0.0421,  1.1335,
#           0.5503,  0.4674, -1.0409, -1.3641,  0.0951, -0.1969, -0.3012, -1.2241,
#           0.2720,  0.4636, -0.2823,  0.0644, -0.0477,  0.1121,  0.1103,  0.1176,
#          -0.0909, -0.8679,  0.4638, -1.0477,  0.8122, -0.8526,  0.3300, -0.4932,
#          -1.2604, -0.2287, -0.5543,  0.4901,  0.2457, -0.2404,  0.1568, -0.4493,
#          -0.1142,  0.7626, -0.8642, -0.1616,  0.3260, -0.6186, -0.4034,  0.6322,
#           0.5962,  0.4219, -0.5550, -0.7066, -0.2851,  0.7625,  0.0193, -0.0353,
#          -0.1064, -0.1582, -0.8139, -0.5608,  0.6944,  0.3231,  0.7020,  0.0328,
#          -0.4303]], grad_fn=<AddmmBackward0>)
#   Bass logits:
#  tensor([[-1.3822,  0.2260, -0.5919, -0.1568, -0.6652, -0.1333,  0.2565, -1.1283,
#          -0.3528, -0.1756,  0.8251,  0.5093, -0.2510, -1.2755, -0.7570, -0.4399,
#          -0.2181, -0.4005,  0.8772,  1.9784,  0.1714,  0.5164,  0.2481,  0.3336,
#           0.0322, -0.4467, -0.3424, -0.2111,  0.0668,  0.1246,  0.5421, -0.0640,
#           0.7233,  0.3595,  0.3353, -1.1069,  0.6920,  0.5405,  0.2940, -0.4749,
#          -0.6117, -0.4759, -1.1625,  0.2068,  0.4141,  0.3762, -0.4081, -0.0428,
#           0.4429, -0.1772,  0.8849, -0.6626, -0.0443, -0.5594, -0.3237, -0.3368,
#          -0.5966, -0.7211, -0.4652,  0.9157, -0.1852, -0.0493,  1.3608, -0.5716,
#           0.4192, -0.4817,  0.5056, -1.7250, -0.9547, -0.1064, -0.8662, -0.0330,
#           0.7187, -0.2429, -0.9631, -0.6292,  0.6968,  0.5164,  0.1954, -0.9089,
#           0.2524, -0.4176,  0.4264,  0.3880,  0.3113, -0.5541, -0.5874, -0.3489,
#          -0.5002,  0.3166,  0.5759, -0.3668,  0.4843,  0.0611, -0.0263, -1.1049,
#          -0.3379,  0.0795,  0.0583, -0.6419, -0.8414,  0.3298,  0.2383,  0.6270,
#           1.2089, -0.6870,  0.2615,  0.0947,  0.6220, -0.0404, -0.0929, -1.0521,
#           0.3183, -0.4991, -0.5917,  0.1373,  0.1367,  0.5307,  1.5469, -0.7684,
#           0.1510,  0.6980, -0.7033,  0.2332,  0.0145, -0.3589,  0.1072,  0.4874,
#           0.0933]], grad_fn=<AddmmBackward0>)
#   Use teacher forcing: True
#   Using ground truth triple:
#  tensor([[[125,  17,  56]]])
#   Updated ys:
#  tensor([[[128, 128, 128],
#          [ 87,  41,  35],
#          [108, 108,  31],
#          [ 18,  73,  42],
#          [ 12,  12,  19],
#          [ 83,  12, 108],
#          [ 29,  44,  91],
#          [106, 117,  50],
#          [106, 105,  19],
#          [ 34,  48,  30],
#          [125,  17,  56]]])
#
# Final generated sequence:
# tensor([[[128, 128, 128],
#          [ 87,  41,  35],
#          [108, 108,  31],
#          [ 18,  73,  42],
#          [ 12,  12,  19],
#          [ 83,  12, 108],
#          [ 29,  44,  91],
#          [106, 117,  50],
#          [106, 105,  19],
#          [ 34,  48,  30],
#          [125,  17,  56]]])
